# %% [markdown]
# # Downscaling Windspeed for **Manhattan**
#
# **Variables:**
# * Variable to be downscaled: Wind Speed (WS)
# * Predictor variable: Surface Pressure (PSFC)
#
# **Dataset Resolutions:**
# * uWRF (Domain 02): 3-hourly, 3 km
# * NAM: 3-hourly, 12 km
#
# **Spatial Coverage:**
# * 2,205.41 km²

# %% [markdown]
# # Import libraries

# %%
import xarray as xr
import numpy as np
import ecubevis as ecv
import scipy as sp
import netCDF4 as nc
import dl4ds as dds
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras import models
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# 2025-01-24 13:06:12.856044: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-24 13:06:12.906550: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-24 13:06:12.907569: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-24 13:06:14.385391: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# !python --version
# Out:
# Python 3.8.18

# %% [markdown]
# # Define paths and retrieve files from server

# %%
uwrf_train = xr.open_dataset('/D4/data/gvaillant/prep-uwrf/d02/wind-NYC-split/train/uWRF_final_01-02.nc')
uwrf_val = xr.open_dataset('/D4/data/gvaillant/prep-uwrf/d02/wind-NYC-split/val/uWRF_final_03.nc')
uwrf_test = xr.open_dataset('/D4/data/gvaillant/prep-uwrf/d02/wind-NYC-split/test/uWRF_final_03.nc')

nam_train = xr.open_dataset('/home/gvaillant1/downscaling/data/WS-NYC-data/aligned_nam_train_data.nc')
nam_val = xr.open_dataset('/home/gvaillant1/downscaling/data/WS-NYC-data/aligned_nam_val_data.nc')
nam_test = xr.open_dataset('/home/gvaillant1/downscaling/data/WS-NYC-data/aligned_nam_test_data.nc')

# %% [markdown]
# # Define variables

# %%
#High resolution (uWRF) data
WS_hr_train = uwrf_train.WS
WS_hr_val = uwrf_val.WS
WS_hr_test = uwrf_test.WS

PSFC_hr_train = uwrf_train.PSFC
PSFC_hr_val = uwrf_val.PSFC
PSFC_hr_test = uwrf_test.PSFC

#--------------------------
#Low resolution (NAM) data
WS_lr_train = nam_train.WS
WS_lr_val = nam_val.WS
WS_lr_test = nam_test.WS

PSFC_lr_train = nam_train.PSFC
PSFC_lr_val = nam_val.PSFC
PSFC_lr_test = nam_test.PSFC

# %% [markdown]
# # Scale the data

# %%
WS_scaler_train = dds.StandardScaler(axis=None)
WS_scaler_train.fit(WS_hr_train)  

PSFC_scaler_train = dds.StandardScaler(axis=None)
PSFC_scaler_train.fit(PSFC_hr_train)
#----------------------------------------------
#High resolution (uWRF):
y_train = WS_scaler_train.transform(WS_hr_train)
y_val = WS_scaler_train.transform(WS_hr_val)
y_test = WS_scaler_train.transform(WS_hr_test)


y_z_train = PSFC_scaler_train.transform(PSFC_hr_train)
y_z_val = PSFC_scaler_train.transform(PSFC_hr_val)
y_z_test = PSFC_scaler_train.transform(PSFC_hr_test)

#-------------------------------------------------
#Low resolution (NAM)

x_train = WS_scaler_train.transform(WS_lr_train)
x_val = WS_scaler_train.transform(WS_lr_val)
x_test = WS_scaler_train.transform(WS_lr_test)

x_z_train = PSFC_scaler_train.transform(PSFC_lr_train)
x_z_val = PSFC_scaler_train.transform(PSFC_lr_val)
x_z_test = PSFC_scaler_train.transform(PSFC_lr_test)

# %% [markdown]
# # Compare original resolutions

# %%
#WS: Wind Speed
ecv.plot((x_train[0].values, y_train[0]), subplot_titles=('NAM: WS', 'uWRF: WS'))

# %%
#PSFC: Surface Pressure
ecv.plot((x_z_train[0].values, y_z_train[0]), subplot_titles=('NAM: PSFC', 'uWRF: PSFC'))

# %% [markdown]
# # Add channel dimension

# %%
y_train = y_train.expand_dims(dim='channel', axis=-1)
y_val = y_val.expand_dims(dim='channel', axis=-1)
y_test = y_test.expand_dims(dim='channel', axis=-1)

y_z_train = y_z_train.expand_dims(dim ='channel', axis=-1)
y_z_val = y_z_val.expand_dims(dim ='channel', axis=-1)
y_z_test = y_z_test.expand_dims(dim ='channel', axis=-1)

#-----------------------------------------------------

x_train = x_train.expand_dims(dim='channel', axis=-1)
x_val = x_val.expand_dims(dim='channel', axis=-1)
x_test = x_test.expand_dims(dim='channel', axis=-1)

x_z_train = x_z_train.expand_dims(dim ='channel', axis=-1)
x_z_val = x_z_val.expand_dims(dim ='channel', axis=-1)
x_z_test = x_z_test.expand_dims(dim ='channel', axis=-1)

# %% [markdown]
# # Verify shape

# %%
print("Wind Speed hr data shape:")
print(y_train.shape, y_val.shape, y_test.shape)
print("")
print("PSFC hr data shape:")
print(y_z_train.shape, y_z_val.shape, y_z_test.shape)
print("")
print("Wind Speed lr data shape:")
print(x_train.shape, x_val.shape, x_test.shape)
print("")
print("PSFC lr data shape:")
print(x_z_train.shape, x_z_val.shape, x_z_test.shape)
# Out:
# Wind Speed hr data shape:
# (1537, 20, 20, 1) (899, 20, 20, 1) (899, 20, 20, 1)
#
# PSFC hr data shape:
# (1537, 20, 20, 1) (899, 20, 20, 1) (899, 20, 20, 1)
#
# Wind Speed lr data shape:
# (1537, 5, 5, 1) (449, 5, 5, 1) (450, 5, 5, 1)
#
# PSFC lr data shape:
# (1537, 5, 5, 1) (449, 5, 5, 1) (450, 5, 5, 1)

# %% [markdown]
# # Example coarsening method occuring during training:
#
# For this model, we do not use the LR data (NAM) during training. Instead, we use a coarsened version (via interpolation) of the HR (uWRF) WS and PSFC data. The DL4DS model carries out this interpolation on the fly by using the helper function dds.create_pair_hr_lr() (not to be called by the user). This process is done **automatically** inside the training loop (by calling one of the two (Supervised vs GAN) Trainer classes in DL4DS), which we examplify here with the spc upsampling.

# %%
_ = dds.create_pair_hr_lr(y_train.values[0], None, 'spc', 4, None, None, y_z_train.values[0], None, True, interpolation='inter_area')
# Out:
# HR array: (20, 20, 1), LR array (5, 5, 2)

# %% [markdown]
# # Training Model
#
# Possible backbones:
#
# * resnet
# * densenet
# * convnet
# * convnext

# %%
backbones = ['resnet', 'densenet']

for backbone in backbones:

    print(f"Running model with backbone={backbone}")
    
    ARCH_PARAMS = dict(n_filters=20,
                       n_blocks=4,
                       normalization=None,
                       dropout_rate=0.5,
                       dropout_variant='spatial',
                       attention=False,
                       activation='relu',
                       localcon_layer=False)

    trainer = dds.SupervisedTrainer(
        backbone=backbone,
        upsampling='spc', 
        data_train=y_train,
        data_val=y_val,
        data_test=y_test,
        data_train_lr=None, # here you can pass the LR dataset for training with explicit paired samples
        data_val_lr=None, # here you can pass the LR dataset for training with explicit paired samples
        data_test_lr=None, # here you can pass the LR dataset for training with explicit paired samples
        scale=4, 
        time_window=None, 
        static_vars=None,
        predictors_train=[y_z_train],
        predictors_val=[y_z_val],
        predictors_test=[y_z_test],
        interpolation='inter_area',
        patch_size=None, 
        batch_size=60,
        loss='mae',
        epochs=50, 
        steps_per_epoch=None, 
        validation_steps=None, 
        test_steps=None, 
        learning_rate=(1e-3, 1e-4), lr_decay_after=1e4,
        early_stopping=False, patience=6, min_delta=0, 
        save=True, 
        save_bestmodel=True,
        save_path='/home/gvaillant1/downscaling/results/WS-NYC-Model',
        show_plot=True, verbose=True, 
        device='CPU',
        **ARCH_PARAMS)
    trainer.run()
# Out:
# Running model with backbone=resnet
# List of devices:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# Number of devices: 1
# Global batch size: 60
# --------------------------------------------------------------------------------
# Starting time: 2025-01-24 13:06:21
# --------------------------------------------------------------------------------
# Model: "resnet_spc"
# ______________________________________________________________________________________________________________________________________________________
#  Layer (type)                                Output Shape                                 Param #        Connected to
# ======================================================================================================================================================
#  input_1 (InputLayer)                        [(None, None, None, 2)]                      0              []
#
#  conv2d (Conv2D)                             (None, None, None, 20)                       380            ['input_1[0][0]']
#
#  ResidualBlock1 (ResidualBlock)              (None, None, None, 20)                       7240           ['conv2d[0][0]']
#
#  ResidualBlock2 (ResidualBlock)              (None, None, None, 40)                       22520          ['ResidualBlock1[0][0]']
#
#  ResidualBlock3 (ResidualBlock)              (None, None, None, 60)                       56580          ['ResidualBlock2[0][0]']
#
#  ResidualBlock4 (ResidualBlock)              (None, None, None, 80)                       105840         ['ResidualBlock3[0][0]']
#
#  conv2d_12 (Conv2D)                          (None, None, None, 80)                       57680          ['ResidualBlock4[0][0]']
#
#  transition_block (TransitionBlock)          (None, None, None, 80)                       1680           ['conv2d[0][0]']
#
#  spatial_dropout2d_8 (SpatialDropout2D)      (None, None, None, 80)                       0              ['conv2d_12[0][0]']
#
#  add (Add)                                   (None, None, None, 80)                       0              ['transition_block[0][0]',
#                                                                                                           'spatial_dropout2d_8[0][0]']
#
#  SubpixelConvolution (SubpixelConvolutionBl  (None, None, None, 80)                       230720         ['add[0][0]']
#  ock)
#
#  TransitionLast (TransitionBlock)            (None, None, None, 20)                       1620           ['SubpixelConvolution[0][0]']
#
#  conv_block (ConvBlock)                      (None, None, None, 20)                       7465           ['TransitionLast[0][0]']
#
#  conv_block_1 (ConvBlock)                    (None, None, None, 1)                        191            ['conv_block[0][0]']
#
# ======================================================================================================================================================
# Total params: 491916 (1.88 MB)
# Trainable params: 491916 (1.88 MB)
# Non-trainable params: 0 (0.00 Byte)
# ______________________________________________________________________________________________________________________________________________________
# Epoch 1/50
# 25/25 [==============================] - 13s 321ms/step - loss: 0.5107 - val_loss: 0.2700
# Epoch 2/50
# 25/25 [==============================] - 8s 313ms/step - loss: 0.2286 - val_loss: 0.1387
# Epoch 3/50
# 25/25 [==============================] - 7s 280ms/step - loss: 0.1778 - val_loss: 0.1181
# Epoch 4/50
# 25/25 [==============================] - 5s 219ms/step - loss: 0.1576 - val_loss: 0.1082
# Epoch 5/50
# 25/25 [==============================] - 6s 254ms/step - loss: 0.1426 - val_loss: 0.0957
# Epoch 6/50
# 25/25 [==============================] - 7s 294ms/step - loss: 0.1330 - val_loss: 0.0942
# Epoch 7/50
# 25/25 [==============================] - 6s 259ms/step - loss: 0.1270 - val_loss: 0.0943
# Epoch 8/50
# 25/25 [==============================] - 7s 291ms/step - loss: 0.1256 - val_loss: 0.0839
# Epoch 9/50
# 25/25 [==============================] - 6s 252ms/step - loss: 0.1206 - val_loss: 0.0844
# Epoch 10/50
# 25/25 [==============================] - 5s 189ms/step - loss: 0.1178 - val_loss: 0.0784
# Epoch 11/50
# 25/25 [==============================] - 6s 241ms/step - loss: 0.1191 - val_loss: 0.0954
# Epoch 12/50
# 25/25 [==============================] - 7s 286ms/step - loss: 0.1130 - val_loss: 0.0837
# Epoch 13/50
# 25/25 [==============================] - 7s 273ms/step - loss: 0.1102 - val_loss: 0.0862
# Epoch 14/50
# 25/25 [==============================] - 8s 322ms/step - loss: 0.1083 - val_loss: 0.0772
# Epoch 15/50
# 25/25 [==============================] - 6s 227ms/step - loss: 0.1061 - val_loss: 0.0777
# Epoch 16/50
# 25/25 [==============================] - 5s 205ms/step - loss: 0.1039 - val_loss: 0.0721
# Epoch 17/50
# 25/25 [==============================] - 7s 274ms/step - loss: 0.1078 - val_loss: 0.1008
# Epoch 18/50
# 25/25 [==============================] - 7s 291ms/step - loss: 0.1063 - val_loss: 0.0707
# Epoch 19/50
# 25/25 [==============================] - 7s 300ms/step - loss: 0.1021 - val_loss: 0.0679
# Epoch 20/50
# 25/25 [==============================] - 6s 258ms/step - loss: 0.1014 - val_loss: 0.0724
# Epoch 21/50
# 25/25 [==============================] - 6s 229ms/step - loss: 0.1004 - val_loss: 0.0682
# Epoch 22/50
# 25/25 [==============================] - 5s 208ms/step - loss: 0.0988 - val_loss: 0.0667
# Epoch 23/50
# 25/25 [==============================] - 7s 295ms/step - loss: 0.0971 - val_loss: 0.0703
# Epoch 24/50
# 25/25 [==============================] - 7s 276ms/step - loss: 0.0967 - val_loss: 0.0663
# Epoch 25/50
# 25/25 [==============================] - 7s 301ms/step - loss: 0.0965 - val_loss: 0.0670
# Epoch 26/50
# 25/25 [==============================] - 6s 260ms/step - loss: 0.0977 - val_loss: 0.0674
# Epoch 27/50
# 25/25 [==============================] - 5s 206ms/step - loss: 0.0933 - val_loss: 0.0631
# Epoch 28/50
# 25/25 [==============================] - 6s 248ms/step - loss: 0.0926 - val_loss: 0.0635
# Epoch 29/50
# 25/25 [==============================] - 7s 290ms/step - loss: 0.0925 - val_loss: 0.0706
# Epoch 30/50
# 25/25 [==============================] - 6s 265ms/step - loss: 0.0913 - val_loss: 0.0626
# Epoch 31/50
# 25/25 [==============================] - 7s 288ms/step - loss: 0.0921 - val_loss: 0.0705
# Epoch 32/50
# 25/25 [==============================] - 6s 253ms/step - loss: 0.0929 - val_loss: 0.0653
# Epoch 33/50
# 25/25 [==============================] - 4s 180ms/step - loss: 0.0905 - val_loss: 0.0688
# Epoch 34/50
# 25/25 [==============================] - 7s 294ms/step - loss: 0.0901 - val_loss: 0.0602
# Epoch 35/50
# 25/25 [==============================] - 6s 260ms/step - loss: 0.0861 - val_loss: 0.0590
# Epoch 36/50
# 25/25 [==============================] - 7s 290ms/step - loss: 0.0871 - val_loss: 0.0659
# Epoch 37/50
# 25/25 [==============================] - 6s 259ms/step - loss: 0.0958 - val_loss: 0.0593
# Epoch 38/50
# 25/25 [==============================] - 6s 240ms/step - loss: 0.0848 - val_loss: 0.0598
# Epoch 39/50
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0844 - val_loss: 0.0611
# Epoch 40/50
# 25/25 [==============================] - 7s 280ms/step - loss: 0.0831 - val_loss: 0.0665
# Epoch 41/50
# 25/25 [==============================] - 7s 269ms/step - loss: 0.0843 - val_loss: 0.0584
# Epoch 42/50
# 25/25 [==============================] - 7s 281ms/step - loss: 0.0830 - val_loss: 0.0647
# Epoch 43/50
# 25/25 [==============================] - 6s 268ms/step - loss: 0.0809 - val_loss: 0.0554
# Epoch 44/50
# 25/25 [==============================] - 5s 224ms/step - loss: 0.0802 - val_loss: 0.0550
# Epoch 45/50
# 25/25 [==============================] - 5s 224ms/step - loss: 0.0800 - val_loss: 0.0551
# Epoch 46/50
# 25/25 [==============================] - 7s 293ms/step - loss: 0.0774 - val_loss: 0.0560
# Epoch 47/50
# 25/25 [==============================] - 7s 271ms/step - loss: 0.0768 - val_loss: 0.0581
# Epoch 48/50
# 25/25 [==============================] - 7s 299ms/step - loss: 0.0769 - val_loss: 0.0548
# Epoch 49/50
# 25/25 [==============================] - 6s 265ms/step - loss: 0.0758 - val_loss: 0.0571
# Epoch 50/50
# 25/25 [==============================] - 5s 211ms/step - loss: 0.0751 - val_loss: 0.0513
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0518
#
# Score on the test set: 0.05175592005252838
# --------------------------------------------------------------------------------
# Final running time: 0:05:26.037817
# --------------------------------------------------------------------------------
# Running model with backbone=densenet
# List of devices:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# Number of devices: 1
# Global batch size: 60
# --------------------------------------------------------------------------------
# Starting time: 2025-01-24 13:11:51
# --------------------------------------------------------------------------------
# Model: "densenet_spc"
# ______________________________________________________________________________________________________________________________________________________
#  Layer (type)                                Output Shape                                 Param #        Connected to
# ======================================================================================================================================================
#  input_2 (InputLayer)                        [(None, None, None, 2)]                      0              []
#
#  conv2d_24 (Conv2D)                          (None, None, None, 20)                       380            ['input_2[0][0]']
#
#  DenseBlock1 (DenseBlock)                    (None, None, None, 40)                       16100          ['conv2d_24[0][0]']
#
#  Transition1 (TransitionBlock)               (None, None, None, 20)                       820            ['DenseBlock1[0][0]']
#
#  DenseBlock2 (DenseBlock)                    (None, None, None, 60)                       61000          ['Transition1[0][0]']
#
#  Transition2 (TransitionBlock)               (None, None, None, 30)                       1830           ['DenseBlock2[0][0]']
#
#  DenseBlock3 (DenseBlock)                    (None, None, None, 90)                       137100         ['Transition2[0][0]']
#
#  Transition3 (TransitionBlock)               (None, None, None, 45)                       4095           ['DenseBlock3[0][0]']
#
#  DenseBlock4 (DenseBlock)                    (None, None, None, 125)                      245200         ['Transition3[0][0]']
#
#  Transition4 (TransitionBlock)               (None, None, None, 62)                       7812           ['DenseBlock4[0][0]']
#
#  conv2d_45 (Conv2D)                          (None, None, None, 80)                       44720          ['Transition4[0][0]']
#
#  spatial_dropout2d_17 (SpatialDropout2D)     (None, None, None, 80)                       0              ['conv2d_45[0][0]']
#
#  concatenate_4 (Concatenate)                 (None, None, None, 100)                      0              ['conv2d_24[0][0]',
#                                                                                                           'spatial_dropout2d_17[0][0]']
#
#  TransitionBackboneLast (TransitionBlock)    (None, None, None, 80)                       8080           ['concatenate_4[0][0]']
#
#  SubpixelConvolution (SubpixelConvolutionBl  (None, None, None, 80)                       230720         ['TransitionBackboneLast[0][0]']
#  ock)
#
#  TransitionLast (TransitionBlock)            (None, None, None, 20)                       1620           ['SubpixelConvolution[0][0]']
#
#  conv_block_2 (ConvBlock)                    (None, None, None, 20)                       7465           ['TransitionLast[0][0]']
#
#  conv_block_3 (ConvBlock)                    (None, None, None, 1)                        191            ['conv_block_2[0][0]']
#
# ======================================================================================================================================================
# Total params: 767133 (2.93 MB)
# Trainable params: 767133 (2.93 MB)
# Non-trainable params: 0 (0.00 Byte)
# ______________________________________________________________________________________________________________________________________________________
# Epoch 1/50
# 25/25 [==============================] - 14s 313ms/step - loss: 0.3986 - val_loss: 0.2052
# Epoch 2/50
# 25/25 [==============================] - 8s 333ms/step - loss: 0.2061 - val_loss: 0.1366
# Epoch 3/50
# 25/25 [==============================] - 7s 281ms/step - loss: 0.1538 - val_loss: 0.1067
# Epoch 4/50
# 25/25 [==============================] - 5s 203ms/step - loss: 0.1371 - val_loss: 0.1157
# Epoch 5/50
# 25/25 [==============================] - 8s 321ms/step - loss: 0.1391 - val_loss: 0.0908
# Epoch 6/50
# 25/25 [==============================] - 7s 290ms/step - loss: 0.1201 - val_loss: 0.0807
# Epoch 7/50
# 25/25 [==============================] - 8s 311ms/step - loss: 0.1110 - val_loss: 0.0725
# Epoch 8/50
# 25/25 [==============================] - 8s 322ms/step - loss: 0.1065 - val_loss: 0.0691
# Epoch 9/50
# 25/25 [==============================] - 5s 211ms/step - loss: 0.1006 - val_loss: 0.0724
# Epoch 10/50
# 25/25 [==============================] - 7s 292ms/step - loss: 0.0986 - val_loss: 0.0745
# Epoch 11/50
# 25/25 [==============================] - 7s 298ms/step - loss: 0.1089 - val_loss: 0.0830
# Epoch 12/50
# 25/25 [==============================] - 7s 304ms/step - loss: 0.1072 - val_loss: 0.0702
# Epoch 13/50
# 25/25 [==============================] - 8s 321ms/step - loss: 0.0934 - val_loss: 0.0642
# Epoch 14/50
# 25/25 [==============================] - 6s 245ms/step - loss: 0.0910 - val_loss: 0.0572
# Epoch 15/50
# 25/25 [==============================] - 5s 225ms/step - loss: 0.0872 - val_loss: 0.0581
# Epoch 16/50
# 25/25 [==============================] - 7s 305ms/step - loss: 0.0877 - val_loss: 0.0609
# Epoch 17/50
# 25/25 [==============================] - 8s 326ms/step - loss: 0.0888 - val_loss: 0.0556
# Epoch 18/50
# 25/25 [==============================] - 7s 295ms/step - loss: 0.0868 - val_loss: 0.0602
# Epoch 19/50
# 25/25 [==============================] - 8s 311ms/step - loss: 0.0871 - val_loss: 0.0569
# Epoch 20/50
# 25/25 [==============================] - 5s 217ms/step - loss: 0.0879 - val_loss: 0.0612
# Epoch 21/50
# 25/25 [==============================] - 7s 293ms/step - loss: 0.0816 - val_loss: 0.0513
# Epoch 22/50
# 25/25 [==============================] - 8s 315ms/step - loss: 0.0823 - val_loss: 0.0503
# Epoch 23/50
# 25/25 [==============================] - 8s 313ms/step - loss: 0.0856 - val_loss: 0.0541
# Epoch 24/50
# 25/25 [==============================] - 7s 292ms/step - loss: 0.0801 - val_loss: 0.0510
# Epoch 25/50
# 25/25 [==============================] - 6s 236ms/step - loss: 0.0801 - val_loss: 0.0501
# Epoch 26/50
# 25/25 [==============================] - 6s 251ms/step - loss: 0.0791 - val_loss: 0.0500
# Epoch 27/50
# 25/25 [==============================] - 7s 306ms/step - loss: 0.0771 - val_loss: 0.0482
# Epoch 28/50
# 25/25 [==============================] - 8s 324ms/step - loss: 0.0762 - val_loss: 0.0481
# Epoch 29/50
# 25/25 [==============================] - 7s 301ms/step - loss: 0.0772 - val_loss: 0.0514
# Epoch 30/50
# 25/25 [==============================] - 7s 285ms/step - loss: 0.0749 - val_loss: 0.0471
# Epoch 31/50
# 25/25 [==============================] - 5s 208ms/step - loss: 0.0747 - val_loss: 0.0594
# Epoch 32/50
# 25/25 [==============================] - 8s 311ms/step - loss: 0.0801 - val_loss: 0.0509
# Epoch 33/50
# 25/25 [==============================] - 8s 319ms/step - loss: 0.0738 - val_loss: 0.0481
# Epoch 34/50
# 25/25 [==============================] - 7s 292ms/step - loss: 0.0754 - val_loss: 0.0507
# Epoch 35/50
# 25/25 [==============================] - 8s 333ms/step - loss: 0.0792 - val_loss: 0.0472
# Epoch 36/50
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0739 - val_loss: 0.0475
# Epoch 37/50
# 25/25 [==============================] - 7s 278ms/step - loss: 0.0721 - val_loss: 0.0452
# Epoch 38/50
# 25/25 [==============================] - 7s 302ms/step - loss: 0.0736 - val_loss: 0.0643
# Epoch 39/50
# 25/25 [==============================] - 7s 284ms/step - loss: 0.0751 - val_loss: 0.0463
# Epoch 40/50
# 25/25 [==============================] - 8s 309ms/step - loss: 0.0796 - val_loss: 0.0588
# Epoch 41/50
# 25/25 [==============================] - 5s 220ms/step - loss: 0.0765 - val_loss: 0.0520
# Epoch 42/50
# 25/25 [==============================] - 6s 252ms/step - loss: 0.0735 - val_loss: 0.0466
# Epoch 43/50
# 25/25 [==============================] - 7s 291ms/step - loss: 0.0713 - val_loss: 0.0521
# Epoch 44/50
# 25/25 [==============================] - 7s 287ms/step - loss: 0.0714 - val_loss: 0.0498
# Epoch 45/50
# 25/25 [==============================] - 8s 314ms/step - loss: 0.0723 - val_loss: 0.0524
# Epoch 46/50
# 20/25 [=======================>......] - ETA: 0s - loss: 0.0775

# %% [markdown]
# # Inference on uWRF test set

# %%
pred = dds.Predictor(
    trainer, 
    y_test, 
    scale=4, 
    array_in_hr=True,
    static_vars=None, 
    predictors=[y_z_test], 
    time_window=None,
    interpolation='inter_area', 
    batch_size=60,
    scaler=WS_scaler_train,
    save_path=None,
    save_fname=None,
    return_lr=True,
    device='CPU')

unscaled_y_pred, coarsened_array = pred.run()

# %% [markdown]
# # Inference on NAM

# %%
pred1 = dds.Predictor(
    trainer, 
    x_train, 
    scale=4, 
    array_in_hr=False,
    static_vars=None, 
    predictors=[x_z_train], 
    time_window=None,
    interpolation='inter_area', 
    batch_size=4,
    scaler=WS_scaler_train,
    save_path=None,
    save_fname=None,
    return_lr=True,
    device='CPU')

unscaled_x_pred, coarsened_array1 = pred1.run()

# %% [markdown]
# # Comparing predictions on uWRF test set

# %%
unscaled_x_test = WS_scaler_train.inverse_transform(x_test)
unscaled_y_test = WS_scaler_train.inverse_transform(y_test)
ecv.plot((unscaled_x_test[0].values, unscaled_y_pred[0], unscaled_y_test[0].values),
         share_colorbar=True, share_dynamic_range=True, subplot_titles=('NAM', 'Downscaled Wind Speed Results', 'uWRF'))

mae = dds.losses.mae(unscaled_y_test[0].values, unscaled_y_pred[0])
print(f"MAE for test set: {mae}")

# %% [markdown]
# # Comparing predictions on NAM data

# %%
unscaled_y_train = WS_scaler_train.inverse_transform(y_train)
unscaled_x_train = WS_scaler_train.inverse_transform(x_train)
ecv.plot((unscaled_x_train[0].values, unscaled_x_pred[0], unscaled_y_train[0].values),
         share_colorbar=True, share_dynamic_range=True, subplot_titles=('NAM', 'Downscaled Wind Speed Results', 'uWRF'))

# %% [markdown]
# # Loss calculations

# %%
mae = dds.losses.mae(unscaled_y_test.values[1], unscaled_y_pred[1])
print(f"MAE for training: {mae}")

mse = dds.losses.mse(unscaled_y_test[0], unscaled_y_pred[0])
print(f"MSE for training: {mse}")
print("")
mae_pred = dds.losses.mae(unscaled_y_test[0], unscaled_x_pred[0])
print(f"MAE on NAM: {mae_pred}")
mse_pred = dds.losses.mse(unscaled_y_test[0], unscaled_x_pred[0])
print(f"MSE on NAM: {mse_pred}")

print("")
if mae == mae_pred:
    print("Same MAE loss value for different unseen datasets.")
else:
    print("MAE loss is not the same")
    

if mse == mse_pred:
    print("Same MSE loss value for different unseen datasets :(")
else:
    print("MSE loss is not the same")

mae_for_preds = dds.losses.mae(unscaled_x_pred[0], unscaled_y_pred[0])
print("MAE between predictions, to see if they're exactly the same:")
print(f"MAE: {mae_for_preds}")
