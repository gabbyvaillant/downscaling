# %% [markdown]
# # Downscaling Windspeed for **Manhattan**
#
# **Variables:**
# * Variable to be downscaled: Wind Speed (WS)
# * Predictor variable: Surface Pressure (PSFC)
#
# **Dataset Resolutions:**
# * uWRF (Domain 02): 3-hourly, 3 km
# * NAM: 3-hourly, 12 km
#
# **Spatial Coverage:**
# * 2,205.41 km²

# %% [markdown]
# # Import libraries

# %%
import xarray as xr
import numpy as np
import ecubevis as ecv
import scipy as sp
import netCDF4 as nc
import dl4ds as dds
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras import models

# %%
# !python --version
# Out:
# Python 3.8.18

# %% [markdown]
# # Define paths and retrieve files from server

# %%
uwrf_train = xr.open_dataset('/D4/data/gvaillant/prep-uwrf/d02/wind-NYC-split/train/uWRF_final_01-02.nc')
uwrf_val = xr.open_dataset('/D4/data/gvaillant/prep-uwrf/d02/wind-NYC-split/val/uWRF_final_03.nc')
uwrf_test = xr.open_dataset('/D4/data/gvaillant/prep-uwrf/d02/wind-NYC-split/test/uWRF_final_03.nc')

nam_train = xr.open_dataset('/home/gvaillant1/downscaling/data/WS-NYC-data/aligned_nam_train_data.nc')
nam_val = xr.open_dataset('/home/gvaillant1/downscaling/data/WS-NYC-data/aligned_nam_val_data.nc')
nam_test = xr.open_dataset('/home/gvaillant1/downscaling/data/WS-NYC-data/aligned_nam_test_data.nc')

# %% [markdown]
# # Define variables

# %%
#High resolution (uWRF) data
WS_hr_train = uwrf_train.WS
WS_hr_val = uwrf_val.WS
WS_hr_test = uwrf_test.WS

PSFC_hr_train = uwrf_train.PSFC
PSFC_hr_val = uwrf_val.PSFC
PSFC_hr_test = uwrf_test.PSFC

#--------------------------
#Low resolution (NAM) data
WS_lr_train = nam_train.WS
WS_lr_val = nam_val.WS
WS_lr_test = nam_test.WS

PSFC_lr_train = nam_train.PSFC
PSFC_lr_val = nam_val.PSFC
PSFC_lr_test = nam_test.PSFC

# %% [markdown]
# # Scale the data

# %%
WS_scaler_train = dds.StandardScaler(axis=None)
WS_scaler_train.fit(WS_hr_train)  

PSFC_scaler_train = dds.StandardScaler(axis=None)
PSFC_scaler_train.fit(PSFC_hr_train)
#----------------------------------------------
#High resolution (uWRF):
y_train = WS_scaler_train.transform(WS_hr_train)
y_val = WS_scaler_train.transform(WS_hr_val)
y_test = WS_scaler_train.transform(WS_hr_test)


y_z_train = PSFC_scaler_train.transform(PSFC_hr_train)
y_z_val = PSFC_scaler_train.transform(PSFC_hr_val)
y_z_test = PSFC_scaler_train.transform(PSFC_hr_test)

#-------------------------------------------------
#Low resolution (NAM)

x_train = WS_scaler_train.transform(WS_lr_train)
x_val = WS_scaler_train.transform(WS_lr_val)
x_test = WS_scaler_train.transform(WS_lr_test)

x_z_train = PSFC_scaler_train.transform(PSFC_lr_train)
x_z_val = PSFC_scaler_train.transform(PSFC_lr_val)
x_z_test = PSFC_scaler_train.transform(PSFC_lr_test)

# %% [markdown]
# # Compare original resolutions

# %%
#WS: Wind Speed
ecv.plot((x_train[0].values, y_train[0]), subplot_titles=('NAM: WS', 'uWRF: WS'))

# %%
#PSFC: Surface Pressure
ecv.plot((x_z_train[0].values, y_z_train[0]), subplot_titles=('NAM: PSFC', 'uWRF: PSFC'))

# %% [markdown]
# # Add channel dimension

# %%
y_train = y_train.expand_dims(dim='channel', axis=-1)
y_val = y_val.expand_dims(dim='channel', axis=-1)
y_test = y_test.expand_dims(dim='channel', axis=-1)

y_z_train = y_z_train.expand_dims(dim ='channel', axis=-1)
y_z_val = y_z_val.expand_dims(dim ='channel', axis=-1)
y_z_test = y_z_test.expand_dims(dim ='channel', axis=-1)

#-----------------------------------------------------

x_train = x_train.expand_dims(dim='channel', axis=-1)
x_val = x_val.expand_dims(dim='channel', axis=-1)
x_test = x_test.expand_dims(dim='channel', axis=-1)

x_z_train = x_z_train.expand_dims(dim ='channel', axis=-1)
x_z_val = x_z_val.expand_dims(dim ='channel', axis=-1)
x_z_test = x_z_test.expand_dims(dim ='channel', axis=-1)

# %% [markdown]
# # Verify shape

# %%
print("Wind Speed hr data shape:")
print(y_train.shape, y_val.shape, y_test.shape)
print("")
print("PSFC hr data shape:")
print(y_z_train.shape, y_z_val.shape, y_z_test.shape)
print("")
print("Wind Speed lr data shape:")
print(x_train.shape, x_val.shape, x_test.shape)
print("")
print("PSFC lr data shape:")
print(x_z_train.shape, x_z_val.shape, x_z_test.shape)
# Out:
# Wind Speed hr data shape:
# (1537, 20, 20, 1) (899, 20, 20, 1) (899, 20, 20, 1)
#
# PSFC hr data shape:
# (1537, 20, 20, 1) (899, 20, 20, 1) (899, 20, 20, 1)
#
# Wind Speed lr data shape:
# (1537, 5, 5, 1) (449, 5, 5, 1) (450, 5, 5, 1)
#
# PSFC lr data shape:
# (1537, 5, 5, 1) (449, 5, 5, 1) (450, 5, 5, 1)

# %% [markdown]
# # Example coarsening method occuring during training:
#
# For this model, we do not use the LR data (NAM) during training. Instead, we use a coarsened version (via interpolation) of the HR (uWRF) WS and PSFC data. The DL4DS model carries out this interpolation on the fly by using the helper function dds.create_pair_hr_lr() (not to be called by the user). This process is done **automatically** inside the training loop (by calling one of the two (Supervised vs GAN) Trainer classes in DL4DS), which we examplify here with the spc upsampling.

# %%
_ = dds.create_pair_hr_lr(y_train.values[0], None, 'spc', 4, None, None, y_z_train.values[0], None, True, interpolation='inter_area')
# Out:
# HR array: (20, 20, 1), LR array (5, 5, 2)

# %% [markdown]
# # Training Model
#
# Possible backbones:
#
# * resnet
# * densenet
# * convnet
# * convnext

# %%
backbones = ['resnet', 'densenet']

for backbone in backbones:

    print(f"Running model with backbone={backbone}")
    
    ARCH_PARAMS = dict(n_filters=20,
                       n_blocks=4,
                       normalization=None,
                       dropout_rate=0.5,
                       dropout_variant='spatial',
                       attention=False,
                       activation='relu',
                       localcon_layer=False)

    trainer = dds.SupervisedTrainer(
        backbone=backbone,
        upsampling='spc', 
        data_train=y_train,
        data_val=y_val,
        data_test=y_test,
        data_train_lr=None, # here you can pass the LR dataset for training with explicit paired samples
        data_val_lr=None, # here you can pass the LR dataset for training with explicit paired samples
        data_test_lr=None, # here you can pass the LR dataset for training with explicit paired samples
        scale=4, 
        time_window=None, 
        static_vars=None,
        predictors_train=[y_z_train],
        predictors_val=[y_z_val],
        predictors_test=[y_z_test],
        interpolation='inter_area',
        patch_size=None, 
        batch_size=60,
        loss='mae',
        epochs=50, 
        steps_per_epoch=None, 
        validation_steps=None, 
        test_steps=None, 
        learning_rate=(1e-3, 1e-4), lr_decay_after=1e4,
        early_stopping=False, patience=6, min_delta=0, 
        save=True, 
        save_bestmodel=True,
        save_path='/home/gvaillant1/downscaling/results/WS-NYC-Model',
        show_plot=True, verbose=True, 
        device='CPU',
        **ARCH_PARAMS)
    trainer.run()
# Out:
# Running model with backbone=resnet
# List of devices:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# Number of devices: 1
# Global batch size: 60
# --------------------------------------------------------------------------------
# Starting time: 2025-01-23 16:23:18
# --------------------------------------------------------------------------------
# Model: "resnet_spc"
# ______________________________________________________________________________________________________________________________________________________
#  Layer (type)                                Output Shape                                 Param #        Connected to
# ======================================================================================================================================================
#  input_5 (InputLayer)                        [(None, None, None, 2)]                      0              []
#
#  conv2d_123 (Conv2D)                         (None, None, None, 20)                       380            ['input_5[0][0]']
#
#  ResidualBlock1 (ResidualBlock)              (None, None, None, 20)                       7240           ['conv2d_123[0][0]']
#
#  ResidualBlock2 (ResidualBlock)              (None, None, None, 40)                       22520          ['ResidualBlock1[0][0]']
#
#  ResidualBlock3 (ResidualBlock)              (None, None, None, 60)                       56580          ['ResidualBlock2[0][0]']
#
#  ResidualBlock4 (ResidualBlock)              (None, None, None, 80)                       105840         ['ResidualBlock3[0][0]']
#
#  conv2d_135 (Conv2D)                         (None, None, None, 80)                       57680          ['ResidualBlock4[0][0]']
#
#  transition_block_1 (TransitionBlock)        (None, None, None, 80)                       1680           ['conv2d_123[0][0]']
#
#  spatial_dropout2d_44 (SpatialDropout2D)     (None, None, None, 80)                       0              ['conv2d_135[0][0]']
#
#  add_1 (Add)                                 (None, None, None, 80)                       0              ['transition_block_1[0][0]',
#                                                                                                           'spatial_dropout2d_44[0][0]']
#
#  SubpixelConvolution (SubpixelConvolutionBl  (None, None, None, 80)                       230720         ['add_1[0][0]']
#  ock)
#
#  TransitionLast (TransitionBlock)            (None, None, None, 20)                       1620           ['SubpixelConvolution[0][0]']
#
#  conv_block_8 (ConvBlock)                    (None, None, None, 20)                       7465           ['TransitionLast[0][0]']
#
#  conv_block_9 (ConvBlock)                    (None, None, None, 1)                        191            ['conv_block_8[0][0]']
#
# ======================================================================================================================================================
# Total params: 491916 (1.88 MB)
# Trainable params: 491916 (1.88 MB)
# Non-trainable params: 0 (0.00 Byte)
# ______________________________________________________________________________________________________________________________________________________
# Epoch 1/50
# 25/25 [==============================] - 35s 847ms/step - loss: 0.4040 - val_loss: 0.2319
# Epoch 2/50
# 25/25 [==============================] - 17s 693ms/step - loss: 0.2196 - val_loss: 0.1451
# Epoch 3/50
# 25/25 [==============================] - 14s 564ms/step - loss: 0.1899 - val_loss: 0.1242
# Epoch 4/50
# 25/25 [==============================] - 14s 569ms/step - loss: 0.1668 - val_loss: 0.1154
# Epoch 5/50
# 25/25 [==============================] - 12s 506ms/step - loss: 0.1505 - val_loss: 0.1015
# Epoch 6/50
# 25/25 [==============================] - 14s 572ms/step - loss: 0.1408 - val_loss: 0.0977
# Epoch 7/50
# 25/25 [==============================] - 12s 480ms/step - loss: 0.1376 - val_loss: 0.0980
# Epoch 8/50
# 25/25 [==============================] - 12s 504ms/step - loss: 0.1341 - val_loss: 0.1200
# Epoch 9/50
# 25/25 [==============================] - 10s 393ms/step - loss: 0.1389 - val_loss: 0.1000
# Epoch 10/50
# 25/25 [==============================] - 13s 534ms/step - loss: 0.1325 - val_loss: 0.0986
# Epoch 11/50
# 25/25 [==============================] - 11s 471ms/step - loss: 0.1244 - val_loss: 0.0898
# Epoch 12/50
# 25/25 [==============================] - 12s 509ms/step - loss: 0.1250 - val_loss: 0.0981
# Epoch 13/50
# 25/25 [==============================] - 9s 361ms/step - loss: 0.1218 - val_loss: 0.0864
# Epoch 14/50
# 25/25 [==============================] - 9s 347ms/step - loss: 0.1220 - val_loss: 0.1070
# Epoch 15/50
# 25/25 [==============================] - 9s 348ms/step - loss: 0.1228 - val_loss: 0.0885
# Epoch 16/50
# 25/25 [==============================] - 9s 350ms/step - loss: 0.1173 - val_loss: 0.0816
# Epoch 17/50
# 25/25 [==============================] - 9s 366ms/step - loss: 0.1153 - val_loss: 0.0824
# Epoch 18/50
# 25/25 [==============================] - 10s 405ms/step - loss: 0.1220 - val_loss: 0.1052
# Epoch 19/50
# 25/25 [==============================] - 8s 336ms/step - loss: 0.1174 - val_loss: 0.0830
# Epoch 20/50
# 25/25 [==============================] - 9s 363ms/step - loss: 0.1112 - val_loss: 0.0822
# Epoch 21/50
# 25/25 [==============================] - 9s 355ms/step - loss: 0.1105 - val_loss: 0.0784
# Epoch 22/50
# 25/25 [==============================] - 9s 365ms/step - loss: 0.1075 - val_loss: 0.0774
# Epoch 23/50
# 25/25 [==============================] - 9s 352ms/step - loss: 0.1058 - val_loss: 0.0764
# Epoch 24/50
# 25/25 [==============================] - 8s 341ms/step - loss: 0.1046 - val_loss: 0.0806
# Epoch 25/50
# 25/25 [==============================] - 9s 371ms/step - loss: 0.1054 - val_loss: 0.0742
# Epoch 26/50
# 25/25 [==============================] - 9s 358ms/step - loss: 0.1035 - val_loss: 0.0762
# Epoch 27/50
# 25/25 [==============================] - 8s 335ms/step - loss: 0.1033 - val_loss: 0.0783
# Epoch 28/50
# 25/25 [==============================] - 8s 310ms/step - loss: 0.1044 - val_loss: 0.0764
# Epoch 29/50
# 25/25 [==============================] - 8s 347ms/step - loss: 0.1022 - val_loss: 0.0768
# Epoch 30/50
# 25/25 [==============================] - 8s 335ms/step - loss: 0.1027 - val_loss: 0.0765
# Epoch 31/50
# 25/25 [==============================] - 8s 339ms/step - loss: 0.0998 - val_loss: 0.0716
# Epoch 32/50
# 25/25 [==============================] - 9s 376ms/step - loss: 0.0992 - val_loss: 0.0701
# Epoch 33/50
# 25/25 [==============================] - 8s 322ms/step - loss: 0.0978 - val_loss: 0.0727
# Epoch 34/50
# 25/25 [==============================] - 9s 372ms/step - loss: 0.0964 - val_loss: 0.0689
# Epoch 35/50
# 25/25 [==============================] - 8s 324ms/step - loss: 0.0975 - val_loss: 0.0696
# Epoch 36/50
# 25/25 [==============================] - 8s 323ms/step - loss: 0.1005 - val_loss: 0.0735
# Epoch 37/50
# 25/25 [==============================] - 9s 357ms/step - loss: 0.0972 - val_loss: 0.0701
# Epoch 38/50
# 25/25 [==============================] - 9s 349ms/step - loss: 0.0935 - val_loss: 0.0646
# Epoch 39/50
# 25/25 [==============================] - 8s 319ms/step - loss: 0.0922 - val_loss: 0.0625
# Epoch 40/50
# 25/25 [==============================] - 8s 323ms/step - loss: 0.0913 - val_loss: 0.0615
# Epoch 41/50
# 25/25 [==============================] - 9s 359ms/step - loss: 0.0933 - val_loss: 0.0653
# Epoch 42/50
# 25/25 [==============================] - 9s 352ms/step - loss: 0.0916 - val_loss: 0.0703
# Epoch 43/50
# 25/25 [==============================] - 8s 334ms/step - loss: 0.0936 - val_loss: 0.0697
# Epoch 44/50
# 25/25 [==============================] - 8s 322ms/step - loss: 0.0903 - val_loss: 0.0605
# Epoch 45/50
# 25/25 [==============================] - 8s 332ms/step - loss: 0.0881 - val_loss: 0.0633
# Epoch 46/50
# 25/25 [==============================] - 8s 333ms/step - loss: 0.0888 - val_loss: 0.0614
# Epoch 47/50
# 25/25 [==============================] - 8s 334ms/step - loss: 0.0883 - val_loss: 0.0558
# Epoch 48/50
# 25/25 [==============================] - 9s 373ms/step - loss: 0.0894 - val_loss: 0.0585
# Epoch 49/50
# 25/25 [==============================] - 9s 355ms/step - loss: 0.0903 - val_loss: 0.0629
# Epoch 50/50
# 25/25 [==============================] - 10s 403ms/step - loss: 0.0903 - val_loss: 0.0613
# 14/14 [==============================] - 1s 33ms/step - loss: 0.0619
#
# Score on the test set: 0.061869580298662186
# --------------------------------------------------------------------------------
# Final running time: 0:08:31.089419
# --------------------------------------------------------------------------------
# Running model with backbone=densenet
# List of devices:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# Number of devices: 1
# Global batch size: 60
# --------------------------------------------------------------------------------
# Starting time: 2025-01-23 16:31:57
# --------------------------------------------------------------------------------
# Model: "densenet_spc"
# ______________________________________________________________________________________________________________________________________________________
#  Layer (type)                                Output Shape                                 Param #        Connected to
# ======================================================================================================================================================
#  input_6 (InputLayer)                        [(None, None, None, 2)]                      0              []
#
#  conv2d_147 (Conv2D)                         (None, None, None, 20)                       380            ['input_6[0][0]']
#
#  DenseBlock1 (DenseBlock)                    (None, None, None, 40)                       16100          ['conv2d_147[0][0]']
#
#  Transition1 (TransitionBlock)               (None, None, None, 20)                       820            ['DenseBlock1[0][0]']
#
#  DenseBlock2 (DenseBlock)                    (None, None, None, 60)                       61000          ['Transition1[0][0]']
#
#  Transition2 (TransitionBlock)               (None, None, None, 30)                       1830           ['DenseBlock2[0][0]']
#
#  DenseBlock3 (DenseBlock)                    (None, None, None, 90)                       137100         ['Transition2[0][0]']
#
#  Transition3 (TransitionBlock)               (None, None, None, 45)                       4095           ['DenseBlock3[0][0]']
#
#  DenseBlock4 (DenseBlock)                    (None, None, None, 125)                      245200         ['Transition3[0][0]']
#
#  Transition4 (TransitionBlock)               (None, None, None, 62)                       7812           ['DenseBlock4[0][0]']
#
#  conv2d_168 (Conv2D)                         (None, None, None, 80)                       44720          ['Transition4[0][0]']
#
#  spatial_dropout2d_53 (SpatialDropout2D)     (None, None, None, 80)                       0              ['conv2d_168[0][0]']
#
#  concatenate_19 (Concatenate)                (None, None, None, 100)                      0              ['conv2d_147[0][0]',
#                                                                                                           'spatial_dropout2d_53[0][0]']
#
#  TransitionBackboneLast (TransitionBlock)    (None, None, None, 80)                       8080           ['concatenate_19[0][0]']
#
#  SubpixelConvolution (SubpixelConvolutionBl  (None, None, None, 80)                       230720         ['TransitionBackboneLast[0][0]']
#  ock)
#
#  TransitionLast (TransitionBlock)            (None, None, None, 20)                       1620           ['SubpixelConvolution[0][0]']
#
#  conv_block_10 (ConvBlock)                   (None, None, None, 20)                       7465           ['TransitionLast[0][0]']
#
#  conv_block_11 (ConvBlock)                   (None, None, None, 1)                        191            ['conv_block_10[0][0]']
#
# ======================================================================================================================================================
# Total params: 767133 (2.93 MB)
# Trainable params: 767133 (2.93 MB)
# Non-trainable params: 0 (0.00 Byte)
# ______________________________________________________________________________________________________________________________________________________
# Epoch 1/50
# 25/25 [==============================] - 16s 417ms/step - loss: 0.4561 - val_loss: 0.2401
# Epoch 2/50
# 25/25 [==============================] - 9s 379ms/step - loss: 0.2397 - val_loss: 0.1563
# Epoch 3/50
# 25/25 [==============================] - 10s 392ms/step - loss: 0.1862 - val_loss: 0.1356
# Epoch 4/50
# 25/25 [==============================] - 9s 377ms/step - loss: 0.1606 - val_loss: 0.1241
# Epoch 5/50
# 25/25 [==============================] - 9s 385ms/step - loss: 0.1504 - val_loss: 0.1191
# Epoch 6/50
# 25/25 [==============================] - 10s 398ms/step - loss: 0.1459 - val_loss: 0.1207
# Epoch 7/50
# 25/25 [==============================] - 9s 363ms/step - loss: 0.1405 - val_loss: 0.1180
# Epoch 8/50
# 25/25 [==============================] - 10s 392ms/step - loss: 0.1376 - val_loss: 0.1111
# Epoch 9/50
# 25/25 [==============================] - 9s 387ms/step - loss: 0.1299 - val_loss: 0.0973
# Epoch 10/50
# 25/25 [==============================] - 9s 383ms/step - loss: 0.1221 - val_loss: 0.0905
# Epoch 11/50
# 25/25 [==============================] - 9s 359ms/step - loss: 0.1185 - val_loss: 0.0889
# Epoch 12/50
# 25/25 [==============================] - 9s 384ms/step - loss: 0.1126 - val_loss: 0.0816
# Epoch 13/50
# 25/25 [==============================] - 10s 413ms/step - loss: 0.1074 - val_loss: 0.0831
# Epoch 14/50
# 25/25 [==============================] - 9s 373ms/step - loss: 0.1050 - val_loss: 0.0727
# Epoch 15/50
# 25/25 [==============================] - 10s 390ms/step - loss: 0.1026 - val_loss: 0.0688
# Epoch 16/50
# 25/25 [==============================] - 9s 351ms/step - loss: 0.1044 - val_loss: 0.0925
# Epoch 17/50
# 25/25 [==============================] - 10s 390ms/step - loss: 0.1030 - val_loss: 0.0658
# Epoch 18/50
# 25/25 [==============================] - 9s 374ms/step - loss: 0.0987 - val_loss: 0.0647
# Epoch 19/50
# 25/25 [==============================] - 10s 415ms/step - loss: 0.0961 - val_loss: 0.0622
# Epoch 20/50
# 25/25 [==============================] - 9s 356ms/step - loss: 0.0944 - val_loss: 0.0688
# Epoch 21/50
# 25/25 [==============================] - 9s 375ms/step - loss: 0.0937 - val_loss: 0.0620
# Epoch 22/50
# 25/25 [==============================] - 9s 378ms/step - loss: 0.0962 - val_loss: 0.0614
# Epoch 23/50
# 25/25 [==============================] - 8s 343ms/step - loss: 0.0926 - val_loss: 0.0614
# Epoch 24/50
# 25/25 [==============================] - 9s 388ms/step - loss: 0.0947 - val_loss: 0.0646
# Epoch 25/50
# 25/25 [==============================] - 9s 349ms/step - loss: 0.0916 - val_loss: 0.0620
# Epoch 26/50
# 25/25 [==============================] - 10s 394ms/step - loss: 0.0917 - val_loss: 0.0663
# Epoch 27/50
# 25/25 [==============================] - 8s 323ms/step - loss: 0.0921 - val_loss: 0.0596
# Epoch 28/50
# 25/25 [==============================] - 6s 241ms/step - loss: 0.0900 - val_loss: 0.0590
# Epoch 29/50
# 25/25 [==============================] - 5s 212ms/step - loss: 0.0948 - val_loss: 0.0677
# Epoch 30/50
# 25/25 [==============================] - 6s 251ms/step - loss: 0.0912 - val_loss: 0.0604
# Epoch 31/50
# 25/25 [==============================] - 6s 247ms/step - loss: 0.0896 - val_loss: 0.0609
# Epoch 32/50
# 25/25 [==============================] - 6s 239ms/step - loss: 0.0914 - val_loss: 0.0776
# Epoch 33/50
# 25/25 [==============================] - 6s 260ms/step - loss: 0.0910 - val_loss: 0.0582
# Epoch 34/50
# 25/25 [==============================] - 6s 245ms/step - loss: 0.0909 - val_loss: 0.0616
# Epoch 35/50
# 25/25 [==============================] - 6s 261ms/step - loss: 0.0896 - val_loss: 0.0573
# Epoch 36/50
# 25/25 [==============================] - 6s 227ms/step - loss: 0.0885 - val_loss: 0.0583
# Epoch 37/50
# 25/25 [==============================] - 6s 239ms/step - loss: 0.0891 - val_loss: 0.0650
# Epoch 38/50
# 25/25 [==============================] - 5s 216ms/step - loss: 0.0888 - val_loss: 0.0598
# Epoch 39/50
# 25/25 [==============================] - 6s 234ms/step - loss: 0.0885 - val_loss: 0.0576
# Epoch 40/50
# 25/25 [==============================] - 6s 258ms/step - loss: 0.0884 - val_loss: 0.0590
# Epoch 41/50
# 25/25 [==============================] - 6s 257ms/step - loss: 0.0885 - val_loss: 0.0565
# Epoch 42/50
# 25/25 [==============================] - 7s 276ms/step - loss: 0.0865 - val_loss: 0.0549
# Epoch 43/50
# 25/25 [==============================] - 6s 233ms/step - loss: 0.0886 - val_loss: 0.0566
# Epoch 44/50
# 25/25 [==============================] - 6s 246ms/step - loss: 0.0862 - val_loss: 0.0574
# Epoch 45/50
# 25/25 [==============================] - 5s 224ms/step - loss: 0.0882 - val_loss: 0.0572
# Epoch 46/50
# 25/25 [==============================] - 6s 257ms/step - loss: 0.0884 - val_loss: 0.0578
# Epoch 47/50
# 25/25 [==============================] - 6s 235ms/step - loss: 0.0880 - val_loss: 0.0561
# Epoch 48/50
# 25/25 [==============================] - 8s 325ms/step - loss: 0.0886 - val_loss: 0.0567
# Epoch 49/50
# 25/25 [==============================] - 5s 207ms/step - loss: 0.0881 - val_loss: 0.0572
# Epoch 50/50
# 25/25 [==============================] - 5s 200ms/step - loss: 0.0870 - val_loss: 0.0569
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0572
#
# Score on the test set: 0.057160381227731705
# --------------------------------------------------------------------------------
# Final running time: 0:06:39.513456
# --------------------------------------------------------------------------------

# %% [markdown]
# # Inference on uWRF test set

# %%
pred = dds.Predictor(
    trainer, 
    y_test, 
    scale=4, 
    array_in_hr=True,
    static_vars=None, 
    predictors=[y_z_test], 
    time_window=None,
    interpolation='inter_area', 
    batch_size=60,
    scaler=WS_scaler_train,
    save_path=None,
    save_fname=None,
    return_lr=True,
    device='CPU')

unscaled_y_pred, coarsened_array = pred.run()
# Out:
# --------------------------------------------------------------------------------
# Starting time: 2025-01-23 15:14:19
# --------------------------------------------------------------------------------
# 15/15 [==============================] - 2s 88ms/step
# --------------------------------------------------------------------------------
# Final running time: 0:00:02.397459
# --------------------------------------------------------------------------------

# %% [markdown]
# # Inference on NAM

# %%
pred1 = dds.Predictor(
    trainer, 
    x_train, 
    scale=4, 
    array_in_hr=False,
    static_vars=None, 
    predictors=[x_z_train], 
    time_window=None,
    interpolation='inter_area', 
    batch_size=4,
    scaler=WS_scaler_train,
    save_path=None,
    save_fname=None,
    return_lr=True,
    device='CPU')

unscaled_x_pred, coarsened_array1 = pred1.run()
# Out:
# --------------------------------------------------------------------------------
# Starting time: 2025-01-23 15:14:21
# --------------------------------------------------------------------------------
# 385/385 [==============================] - 5s 13ms/step
# --------------------------------------------------------------------------------
# Final running time: 0:00:05.677929
# --------------------------------------------------------------------------------

# %% [markdown]
# # Comparing predictions on uWRF test set

# %%
unscaled_x_test = WS_scaler_train.inverse_transform(x_test)
unscaled_y_test = WS_scaler_train.inverse_transform(y_test)
ecv.plot((unscaled_x_test[0].values, unscaled_y_pred[0], unscaled_y_test[0].values),
         share_colorbar=True, share_dynamic_range=True, subplot_titles=('NAM', 'Downscaled Wind Speed Results', 'uWRF'))

mae = dds.losses.mae(unscaled_y_test[0].values, unscaled_y_pred[0])
print(f"MAE for test set: {mae}")
# Out:
# MAE for test set: 0.06025733798742294

# %% [markdown]
# # Comparing predictions on NAM data

# %%
unscaled_y_train = WS_scaler_train.inverse_transform(y_train)
unscaled_x_train = WS_scaler_train.inverse_transform(x_train)
ecv.plot((unscaled_x_train[0].values, unscaled_x_pred[0], unscaled_y_train[0].values),
         share_colorbar=True, share_dynamic_range=True, subplot_titles=('NAM', 'Downscaled Wind Speed Results', 'uWRF'))

# %% [markdown]
# # Loss calculations

# %%
mae = dds.losses.mae(unscaled_y_test.values[1], unscaled_y_pred[1])
print(f"MAE for training: {mae}")

mse = dds.losses.mse(unscaled_y_test[0], unscaled_y_pred[0])
print(f"MSE for training: {mse}")
print("")
mae_pred = dds.losses.mae(unscaled_y_test[0], unscaled_x_pred[0])
print(f"MAE on NAM: {mae_pred}")
mse_pred = dds.losses.mse(unscaled_y_test[0], unscaled_x_pred[0])
print(f"MSE on NAM: {mse_pred}")

print("")
if mae == mae_pred:
    print("Same MAE loss value for different unseen datasets.")
else:
    print("MAE loss is not the same")
    

if mse == mse_pred:
    print("Same MSE loss value for different unseen datasets :(")
else:
    print("MSE loss is not the same")

mae_for_preds = dds.losses.mae(unscaled_x_pred[0], unscaled_y_pred[0])
print("MAE between predictions, to see if they're exactly the same:")
print(f"MAE: {mae_for_preds}")
# Out:
# MAE for training: 0.09177543222904205
# MSE for training: 0.022765913978219032
#
# MAE on NAM: 2.295362949371338
# MSE on NAM: 5.483877658843994
#
# MAE loss is not the same
# MSE loss is not the same
# MAE between predictions, to see if they're exactly the same:
# MAE: 2.298806667327881
