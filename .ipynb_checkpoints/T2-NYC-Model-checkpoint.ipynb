# %% [markdown]
# # Applying PerfectProg training to uWRF d02 NYC
# # Scale by 4 (3km x4 = 12 km)
#
# Then once we have the dimensions all set (time, latitude, longitude) we need to spatially filter it is divisble by 4.

# %%
import xarray as xr
import numpy as np
import ecubevis as ecv
import scipy as sp
import netCDF4 as nc
import dl4ds as dds
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras import models
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# 2025-01-14 13:51:47.545831: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-14 13:51:47.590953: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-14 13:51:47.591818: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-14 13:51:49.204403: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# !python --version
# Out:
# Python 3.8.18

# %%
#FILES CONTAINING ALL PREPROCESSED DATA NEEDED FOR MODEL:
uwrf_train = xr.open_dataset('/D4/data/gvaillant/prep-uwrf/d02/pred-NYC-split/train/uWRF_final_01-02.nc')
uwrf_val = xr.open_dataset('/D4/data/gvaillant/prep-uwrf/d02/pred-NYC-split/val/uWRF_final_03.nc')
uwrf_test = xr.open_dataset('/D4/data/gvaillant/prep-uwrf/d02/pred-NYC-split/test/uWRF_final_03.nc')

nam_train = xr.open_dataset('/home/gvaillant1/aligned-NYC-data/aligned_nam_train_data.nc')
nam_val = xr.open_dataset('/home/gvaillant1/aligned-NYC-data/aligned_nam_test_data.nc')
nam_test = xr.open_dataset('/home/gvaillant1/aligned-NYC-data/aligned_nam_val_data.nc')

# %%
#High resolution (uWRF) data
T2_hr_train = uwrf_train.T2
T2_hr_val = uwrf_val.T2
T2_hr_test = uwrf_test.T2

PRES_hr_train = uwrf_train.PSFC
PRES_hr_val = uwrf_val.PSFC
PRES_hr_test = uwrf_test.PSFC

#--------------------------
#Low resolution (NAM) data
T2_lr_train = nam_train.T2
T2_lr_val = nam_val.T2
T2_lr_test = nam_test.T2

PRES_lr_train = nam_train.PSFC
PRES_lr_val = nam_val.PSFC
PRES_lr_test = nam_test.PSFC

# %%
T2_scaler_train = dds.StandardScaler(axis=None)
T2_scaler_train.fit(T2_hr_train)  

PRES_scaler_train = dds.StandardScaler(axis=None)
PRES_scaler_train.fit(PRES_hr_train)
#----------------------------------------------
#High resolution (uWRF):
y_train = T2_scaler_train.transform(T2_hr_train)
y_val = T2_scaler_train.transform(T2_hr_val)
y_test = T2_scaler_train.transform(T2_hr_test)


y_z_train = PRES_scaler_train.transform(PRES_hr_train)
y_z_val = PRES_scaler_train.transform(PRES_hr_val)
y_z_test = PRES_scaler_train.transform(PRES_hr_test)

#-------------------------------------------------
#Low resolution (NAM)

x_train = T2_scaler_train.transform(T2_lr_train)
x_val = T2_scaler_train.transform(T2_lr_val)
x_test = T2_scaler_train.transform(T2_lr_test)

x_z_train = PRES_scaler_train.transform(PRES_lr_train)
x_z_val = PRES_scaler_train.transform(PRES_lr_val)
x_z_test = PRES_scaler_train.transform(PRES_lr_test)

# %%
ecv.plot((x_train[0].values, y_train[0]), subplot_titles=('t2m coarsened', 't2m highres'))

# %%
ecv.plot((x_z_train[0].values, y_z_train[0]), subplot_titles=('surface pressure coarsened', 'surface pressure highres'))

# %%
y_train = y_train.expand_dims(dim='channel', axis=-1)
y_val = y_val.expand_dims(dim='channel', axis=-1)
y_test = y_test.expand_dims(dim='channel', axis=-1)

y_z_train = y_z_train.expand_dims(dim ='channel', axis=-1)
y_z_val = y_z_val.expand_dims(dim ='channel', axis=-1)
y_z_test = y_z_test.expand_dims(dim ='channel', axis=-1)

#-----------------------------------------------------

x_train = x_train.expand_dims(dim='channel', axis=-1)
x_val = x_val.expand_dims(dim='channel', axis=-1)
x_test = x_test.expand_dims(dim='channel', axis=-1)

x_z_train = x_z_train.expand_dims(dim ='channel', axis=-1)
x_z_val = x_z_val.expand_dims(dim ='channel', axis=-1)
x_z_test = x_z_test.expand_dims(dim ='channel', axis=-1)

# %%
print("T2 hr data shape:")
print(y_train.shape, y_val.shape, y_test.shape)
print("")
print("PRES hr data shape:")
print(y_z_train.shape, y_z_val.shape, y_z_test.shape)
print("")
print("T2 lr data shape:")
print(x_train.shape, x_val.shape, x_test.shape)
print("")
print("PRES lr data shape:")
print(x_z_train.shape, x_z_val.shape, x_z_test.shape)
# Out:
# T2 hr data shape:
# (1537, 20, 20, 1) (812, 20, 20, 1) (812, 20, 20, 1)
#
# PRES hr data shape:
# (1537, 20, 20, 1) (812, 20, 20, 1) (812, 20, 20, 1)
#
# T2 lr data shape:
# (1537, 5, 5, 1) (450, 5, 5, 1) (449, 5, 5, 1)
#
# PRES lr data shape:
# (1537, 5, 5, 1) (450, 5, 5, 1) (449, 5, 5, 1)

# %%
#Check for correct creation of the low-res version of uWRF
#This function is called before training begins. This is just an example to show what is going on:

_ = dds.create_pair_hr_lr(y_train.values[0], None, 'spc', 4, None, None, y_z_train.values[0], None, True, interpolation='inter_area')
# Out:
# HR array: (20, 20, 1), LR array (5, 5, 2)

# %% [markdown]
# # Training Model
#
# There are several types of backbones to try, so here we will implement each one and evaluate which performs best.
#
# * resnet: MAE = 0.09434913098812103
# * densenet: MAE = 0.04823455959558487 **best**
# * convnet: MAE = 0.4711471498012543
# * convnext: MAE = doesn't work

# %%
#Need to tune hyperparameters
#Model is currently overfitting
ARCH_PARAMS = dict(n_filters=20,
                   n_blocks=4,
                   normalization='bn', #Batch normalization
                   dropout_rate=0.5,
                   dropout_variant='spatial',
                   attention=False,
                   activation='relu',
                   localcon_layer=False) #when set to true.. it works

trainer = dds.SupervisedTrainer(
    backbone='densenet',
    upsampling='spc', 
    data_train=y_train,
    data_val=y_val,
    data_test=y_test,
    data_train_lr=None, # here you can pass the LR dataset for training with explicit paired samples
    data_val_lr=None, # here you can pass the LR dataset for training with explicit paired samples
    data_test_lr=None, # here you can pass the LR dataset for training with explicit paired samples
    scale=4, 
    time_window=None, 
    static_vars=None,
    predictors_train=[y_z_train],
    predictors_val=[y_z_val],
    predictors_test=[y_z_test],
    interpolation='inter_area',
    patch_size=None, 
    batch_size=60, #changed from 60
    loss='mae',
    epochs=50, 
    steps_per_epoch=None, 
    validation_steps=None, 
    test_steps=None, 
    learning_rate=(1e-3, 1e-4), lr_decay_after=1e4,
    early_stopping=False, patience=6, min_delta=0, 
    save=False, 
    save_path=None,
    show_plot=True, verbose=True, 
    device='CPU',
    **ARCH_PARAMS)
trainer.run()
# Out:
# List of devices:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# Number of devices: 1
# Global batch size: 60
# --------------------------------------------------------------------------------
# Starting time: 2025-01-14 13:51:55
# --------------------------------------------------------------------------------
# Model: "densenet_spc"
# ______________________________________________________________________________________________________________________________________________________
#  Layer (type)                                Output Shape                                 Param #        Connected to
# ======================================================================================================================================================
#  input_1 (InputLayer)                        [(None, None, None, 2)]                      0              []
#
#  conv2d (Conv2D)                             (None, None, None, 20)                       380            ['input_1[0][0]']
#
#  DenseBlock1 (DenseBlock)                    (None, None, None, 40)                       16500          ['conv2d[0][0]']
#
#  Transition1 (TransitionBlock)               (None, None, None, 20)                       820            ['DenseBlock1[0][0]']
#
#  DenseBlock2 (DenseBlock)                    (None, None, None, 60)                       61720          ['Transition1[0][0]']
#
#  Transition2 (TransitionBlock)               (None, None, None, 30)                       1830           ['DenseBlock2[0][0]']
#
#  DenseBlock3 (DenseBlock)                    (None, None, None, 90)                       138180         ['Transition2[0][0]']
#
#  Transition3 (TransitionBlock)               (None, None, None, 45)                       4095           ['DenseBlock3[0][0]']
#
#  DenseBlock4 (DenseBlock)                    (None, None, None, 125)                      246660         ['Transition3[0][0]']
#
#  Transition4 (TransitionBlock)               (None, None, None, 62)                       7812           ['DenseBlock4[0][0]']
#
#  conv2d_21 (Conv2D)                          (None, None, None, 80)                       44720          ['Transition4[0][0]']
#
#  spatial_dropout2d_8 (SpatialDropout2D)      (None, None, None, 80)                       0              ['conv2d_21[0][0]']
#
#  concatenate_4 (Concatenate)                 (None, None, None, 100)                      0              ['conv2d[0][0]',
#                                                                                                           'spatial_dropout2d_8[0][0]']
#
#  TransitionBackboneLast (TransitionBlock)    (None, None, None, 80)                       8080           ['concatenate_4[0][0]']
#
#  SubpixelConvolution (SubpixelConvolutionBl  (None, None, None, 80)                       230720         ['TransitionBackboneLast[0][0]']
#  ock)
#
#  TransitionLast (TransitionBlock)            (None, None, None, 20)                       1620           ['SubpixelConvolution[0][0]']
#
#  conv_block (ConvBlock)                      (None, None, None, 20)                       7585           ['TransitionLast[0][0]']
#
#  conv_block_1 (ConvBlock)                    (None, None, None, 1)                        197            ['conv_block[0][0]']
#
# ======================================================================================================================================================
# Total params: 770919 (2.94 MB)
# Trainable params: 769005 (2.93 MB)
# Non-trainable params: 1914 (7.48 KB)
# ______________________________________________________________________________________________________________________________________________________
# Epoch 1/50
# 25/25 [==============================] - 6s 82ms/step - loss: 0.4386 - val_loss: 3.4745
# Epoch 2/50
# 25/25 [==============================] - 2s 64ms/step - loss: 0.2677 - val_loss: 1.1983
# Epoch 3/50
# 25/25 [==============================] - 2s 64ms/step - loss: 0.2169 - val_loss: 0.6030
# Epoch 4/50
# 25/25 [==============================] - 2s 74ms/step - loss: 0.1960 - val_loss: 0.3962
# Epoch 5/50
# 25/25 [==============================] - 2s 64ms/step - loss: 0.1871 - val_loss: 0.3060
# Epoch 6/50
# 25/25 [==============================] - 2s 63ms/step - loss: 0.1779 - val_loss: 0.2286
# Epoch 7/50
# 25/25 [==============================] - 2s 62ms/step - loss: 0.1718 - val_loss: 0.1385
# Epoch 8/50
# 25/25 [==============================] - 2s 62ms/step - loss: 0.1710 - val_loss: 0.1294
# Epoch 9/50
# 25/25 [==============================] - 2s 63ms/step - loss: 0.1673 - val_loss: 0.2093
# Epoch 10/50
# 25/25 [==============================] - 2s 63ms/step - loss: 0.1679 - val_loss: 0.2157
# Epoch 11/50
# 25/25 [==============================] - 2s 79ms/step - loss: 0.1615 - val_loss: 0.1342
# Epoch 12/50
# 25/25 [==============================] - 2s 65ms/step - loss: 0.1607 - val_loss: 0.1384
# Epoch 13/50
# 25/25 [==============================] - 2s 68ms/step - loss: 0.1583 - val_loss: 0.1311
# Epoch 14/50
# 25/25 [==============================] - 2s 68ms/step - loss: 0.1559 - val_loss: 0.1085
# Epoch 15/50
# 25/25 [==============================] - 2s 64ms/step - loss: 0.1550 - val_loss: 0.1156
# Epoch 16/50
# 25/25 [==============================] - 2s 65ms/step - loss: 0.1525 - val_loss: 0.0677
# Epoch 17/50
# 25/25 [==============================] - 2s 64ms/step - loss: 0.1507 - val_loss: 0.0745
# Epoch 18/50
# 25/25 [==============================] - 2s 63ms/step - loss: 0.1500 - val_loss: 0.0795
# Epoch 19/50
# 25/25 [==============================] - 2s 63ms/step - loss: 0.1485 - val_loss: 0.0995
# Epoch 20/50
# 25/25 [==============================] - 2s 64ms/step - loss: 0.1494 - val_loss: 0.1150
# Epoch 21/50
# 25/25 [==============================] - 2s 66ms/step - loss: 0.1504 - val_loss: 0.1370
# Epoch 22/50
# 25/25 [==============================] - 2s 63ms/step - loss: 0.1480 - val_loss: 0.0812
# Epoch 23/50
# 25/25 [==============================] - 2s 63ms/step - loss: 0.1511 - val_loss: 0.0968
# Epoch 24/50
# 25/25 [==============================] - 2s 62ms/step - loss: 0.1467 - val_loss: 0.1658
# Epoch 25/50
# 25/25 [==============================] - 2s 66ms/step - loss: 0.1441 - val_loss: 0.1017
# Epoch 26/50
# 25/25 [==============================] - 2s 66ms/step - loss: 0.1424 - val_loss: 0.0720
# Epoch 27/50
# 25/25 [==============================] - 2s 64ms/step - loss: 0.1428 - val_loss: 0.0759
# Epoch 28/50
# 25/25 [==============================] - 2s 62ms/step - loss: 0.1423 - val_loss: 0.0718
# Epoch 29/50
# 25/25 [==============================] - 2s 63ms/step - loss: 0.1427 - val_loss: 0.0465
# Epoch 30/50
# 25/25 [==============================] - 2s 62ms/step - loss: 0.1429 - val_loss: 0.0843
# Epoch 31/50
# 25/25 [==============================] - 2s 62ms/step - loss: 0.1407 - val_loss: 0.0526
# Epoch 32/50
# 25/25 [==============================] - 2s 63ms/step - loss: 0.1410 - val_loss: 0.0790
# Epoch 33/50
# 25/25 [==============================] - 2s 62ms/step - loss: 0.1419 - val_loss: 0.0701
# Epoch 34/50
# 25/25 [==============================] - 2s 63ms/step - loss: 0.1400 - val_loss: 0.0963
# Epoch 35/50
# 25/25 [==============================] - 2s 64ms/step - loss: 0.1414 - val_loss: 0.0513
# Epoch 36/50
# 25/25 [==============================] - 2s 63ms/step - loss: 0.1424 - val_loss: 0.1073
# Epoch 37/50
# 25/25 [==============================] - 2s 63ms/step - loss: 0.1398 - val_loss: 0.1094
# Epoch 38/50
# 25/25 [==============================] - 2s 64ms/step - loss: 0.1385 - val_loss: 0.0633
# Epoch 39/50
# 25/25 [==============================] - 2s 63ms/step - loss: 0.1405 - val_loss: 0.0870
# Epoch 40/50
# 25/25 [==============================] - 2s 63ms/step - loss: 0.1369 - val_loss: 0.0506
# Epoch 41/50
# 25/25 [==============================] - 2s 65ms/step - loss: 0.1363 - val_loss: 0.0442
# Epoch 42/50
# 25/25 [==============================] - 2s 65ms/step - loss: 0.1352 - val_loss: 0.0406
# Epoch 43/50
# 25/25 [==============================] - 2s 65ms/step - loss: 0.1351 - val_loss: 0.0473
# Epoch 44/50
# 25/25 [==============================] - 2s 62ms/step - loss: 0.1355 - val_loss: 0.0547
# Epoch 45/50
# 25/25 [==============================] - 2s 63ms/step - loss: 0.1360 - val_loss: 0.0735
# Epoch 46/50
# 25/25 [==============================] - 2s 62ms/step - loss: 0.1358 - val_loss: 0.0385
# Epoch 47/50
# 25/25 [==============================] - 2s 62ms/step - loss: 0.1352 - val_loss: 0.0519
# Epoch 48/50
# 25/25 [==============================] - 2s 62ms/step - loss: 0.1375 - val_loss: 0.0459
# Epoch 49/50
# 25/25 [==============================] - 2s 63ms/step - loss: 0.1358 - val_loss: 0.1026
# Epoch 50/50
# 25/25 [==============================] - 2s 63ms/step - loss: 0.1338 - val_loss: 0.0544
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0549
#
# Score on the test set: 0.05488250032067299
# --------------------------------------------------------------------------------
# Final running time: 0:01:26.813354
# --------------------------------------------------------------------------------

# %%
pred = dds.Predictor(
    trainer, 
    y_test, 
    scale=4, 
    array_in_hr=True,
    static_vars=None, 
    predictors=[y_z_test], 
    time_window=None,
    interpolation='inter_area', 
    batch_size=60,
    scaler=T2_scaler_train,
    save_path=None,
    save_fname=None,
    return_lr=True,
    device='CPU')

unscaled_y_pred, coarsened_array = pred.run()
# Out:
# --------------------------------------------------------------------------------
# Starting time: 2025-01-14 13:54:26
# --------------------------------------------------------------------------------
# 14/14 [==============================] - 0s 16ms/step
# --------------------------------------------------------------------------------
# Final running time: 0:00:00.342874
# --------------------------------------------------------------------------------

# %%
pred1 = dds.Predictor(
    trainer, 
    x_test, 
    scale=4, 
    array_in_hr=False,
    static_vars=None, 
    predictors=[x_z_test], 
    time_window=None,
    interpolation='inter_area', 
    batch_size=60,
    scaler=T2_scaler_train,
    save_path=None,
    save_fname=None,
    return_lr=True,
    device='CPU')

unscaled_x_pred, coarsened_array1 = pred1.run()
# Out:
# --------------------------------------------------------------------------------
# Starting time: 2025-01-14 13:54:29
# --------------------------------------------------------------------------------
# 8/8 [==============================] - 0s 15ms/step
# --------------------------------------------------------------------------------
# Final running time: 0:00:00.209142
# --------------------------------------------------------------------------------

# %% [markdown]
# # Compare training results with the ground truth data (uWRF)

# %%
unscaled_y_test = T2_scaler_train.inverse_transform(y_test)
ecv.plot((unscaled_y_test[0].values, unscaled_y_pred[0]), subplot_titles=('groundtruth t2m', 'downscaled t2m'))

# %% [markdown]
# # Compare results with the original NAM data

# %%
unscaled_x_test = T2_scaler_train.inverse_transform(x_test)
unscaled_x_train = T2_scaler_train.inverse_transform(x_train)
ecv.plot((unscaled_x_test[0].values, unscaled_x_pred[0]), subplot_titles=('original t2m (NAM)', 'downscaled t2m'))

# %% [markdown]
# # Compare results with ground truth data (uWRF)

# %%
ecv.plot((unscaled_y_test[0].values, unscaled_x_pred[0]), subplot_titles=('ground truth t2m (uWRF)', 'downscaled t2m'))

# %% [markdown]
# # Loss

# %%
#These are the same.................................... this is wrong
mae = dds.losses.mae(unscaled_y_test[0], unscaled_y_pred[0])
print(f"MAE for training: {mae}")

mse = dds.losses.mse(unscaled_y_test[0], unscaled_y_pred[0])
print(f"MSE for training: {mse}")
print("")
mae_pred = dds.losses.mae(unscaled_y_test[0], unscaled_x_pred[0])
print(f"MAE on NAM: {mae_pred}")
mse_pred = dds.losses.mse(unscaled_y_test[0], unscaled_x_pred[0])
print(f"MSE on NAM: {mse_pred}")

print("")
if mae == mae_pred:
    print("Same MAE loss value for different unseen datasets.")
else:
    print("MAE loss is not the same")
    

if mse == mse_pred:
    print("Same MSE loss value for different unseen datasets :(")
else:
    print("MSE loss is not the same")
# Out:
# MAE for training: 0.2601684033870697
# MSE for training: 0.08443151414394379
#
# MAE on NAM: 0.26017311215400696
# MSE on NAM: 0.08443455398082733
#
# MAE loss is not the same
# MSE loss is not the same

# %%
ecv.plot(unscaled_y_test.values)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :DynamicMap   [time]
#    :Image   [x,y]   (values)

# %%
#predictors:

ind = 0
ecv.plot((coarsened_array[ind][:,:,0], coarsened_array[ind][:,:,1]), subplot_titles=('t2m', 'surface pressure (predictor)'),)
