# %% [markdown]
# # Applying PerfectProg training to uWRF d02
# # Scale by 4 (3km x4 = 12 km)
#
#
# Don't need to do the first prep step for this because we already have it done. Now im using a new uWRF_match_dims function because the original one was working weird.
#
# Then once we have the dimensions all set (time, latitude, longitude) we need to spatially filter it is divisble by 4.

# %%
import xarray as xr
import numpy as np
import ecubevis as ecv
import scipy as sp
import netCDF4 as nc
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# !python --version
# Out:
# Python 3.8.18

# %% [markdown]
# # Apply ML model

# %%
uwrf_train = xr.open_dataset('/D4/data/gvaillant/prep-uwrf/d02/pred-split/train/uWRF_final_01-02.nc')
uwrf_val = xr.open_dataset('/D4/data/gvaillant/prep-uwrf/d02/pred-split/val/uWRF_final_03.nc')
uwrf_test = xr.open_dataset('/D4/data/gvaillant/prep-uwrf/d02/pred-split/test/uWRF_final_03.nc')

nam_train = xr.open_dataset('/home/gvaillant1/aligned-data/aligned_nam_train_data.nc')
nam_val = xr.open_dataset('/home/gvaillant1/aligned-data/aligned_nam_test_data.nc')
nam_test = xr.open_dataset('/home/gvaillant1/aligned-data/aligned_nam_test_data.nc')

# %%
#High resolution (uWRF) data
T2_hr_train = uwrf_train.T2
T2_hr_val = uwrf_val.T2
T2_hr_test = uwrf_test.T2

PRES_hr_train = uwrf_train.PSFC
PRES_hr_val = uwrf_val.PSFC
PRES_hr_test = uwrf_test.PSFC

#--------------------------
#Low resolution (NAM) data
T2_lr_train = nam_train.T2
T2_lr_val = nam_val.T2
T2_lr_test = nam_test.T2

PRES_lr_train = nam_train.PSFC
PRES_lr_val = nam_val.PSFC
PRES_lr_test = nam_test.PSFC

# %%
import dl4ds as dds
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras import models
# Out:
# 2025-01-06 14:36:42.977828: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-06 14:36:43.023179: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-06 14:36:43.024037: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-06 14:36:44.784226: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
T2_scaler_train = dds.StandardScaler(axis=None)
T2_scaler_train.fit(T2_hr_train)  

PRES_scaler_train = dds.StandardScaler(axis=None)
PRES_scaler_train.fit(PRES_hr_train)
#----------------------------------------------
#High resolution (uWRF):
y_train = T2_scaler_train.transform(T2_hr_train)
y_val = T2_scaler_train.transform(T2_hr_val)
y_test = T2_scaler_train.transform(T2_hr_test)


y_z_train = PRES_scaler_train.transform(PRES_hr_train)
y_z_val = PRES_scaler_train.transform(PRES_hr_val)
y_z_test = PRES_scaler_train.transform(PRES_hr_test)

#-------------------------------------------------
#Low resolution (NAM)

x_train = T2_scaler_train.transform(T2_lr_train)
x_val = T2_scaler_train.transform(T2_lr_val)
x_test = T2_scaler_train.transform(T2_lr_test)

x_z_train = PRES_scaler_train.transform(PRES_lr_train)
x_z_val = PRES_scaler_train.transform(PRES_lr_val)
x_z_test = PRES_scaler_train.transform(PRES_lr_test)

# %%
y_train = y_train.expand_dims(dim='channel', axis=-1)
y_val = y_val.expand_dims(dim='channel', axis=-1)
y_test = y_test.expand_dims(dim='channel', axis=-1)

y_z_train = y_z_train.expand_dims(dim ='channel', axis=-1)
y_z_val = y_z_val.expand_dims(dim ='channel', axis=-1)
y_z_test = y_z_test.expand_dims(dim ='channel', axis=-1)

#-----------------------------------------------------

x_train = x_train.expand_dims(dim='channel', axis=-1)
x_val = x_val.expand_dims(dim='channel', axis=-1)
x_test = x_test.expand_dims(dim='channel', axis=-1)

x_z_train = x_z_train.expand_dims(dim ='channel', axis=-1)
x_z_val = x_z_val.expand_dims(dim ='channel', axis=-1)
x_z_test = x_z_test.expand_dims(dim ='channel', axis=-1)

# %%
print("T2 hr data shape:")
print(y_train.shape, y_val.shape, y_test.shape)
print("")
print("PRES hr data shape:")
print(y_z_train.shape, y_z_val.shape, y_z_test.shape)
print("")
print("T2 lr data shape:")
print(x_train.shape, x_val.shape, x_test.shape)
print("")
print("PRES lr data shape:")
print(x_z_train.shape, x_z_val.shape, x_z_test.shape)
# Out:
# T2 hr data shape:
# (1537, 120, 120, 1) (870, 120, 120, 1) (870, 120, 120, 1)
#
# PRES hr data shape:
# (1537, 120, 120, 1) (870, 120, 120, 1) (870, 120, 120, 1)
#
# T2 lr data shape:
# (1537, 30, 30, 1) (450, 30, 30, 1) (450, 30, 30, 1)
#
# PRES lr data shape:
# (1537, 30, 30, 1) (450, 30, 30, 1) (450, 30, 30, 1)

# %%
#Check for correct creation of the low-res version of uWRF
#This function is called before training begins. This is just an example to show what is going on:

_ = dds.create_pair_hr_lr(y_train.values[0], None, 'spc', 4, None, None, y_z_train.values[0], None, True, interpolation='inter_area')
# Out:
# HR array: (120, 120, 1), LR array (30, 30, 2)

# %% [markdown]
# # Training Model
#
# There are several types of backbones to try, so here we will implement each one and evaluate which performs best.
#
# * resnet
# * densenet
# * convnet
# * convnext

# %%
#Implementing resnet
ARCH_PARAMS = dict(n_filters=8,
                   n_blocks=8,
                   normalization=None,
                   dropout_rate=0.0,
                   dropout_variant='spatial',
                   attention=False,
                   activation='relu',
                   localcon_layer=False)

trainer = dds.SupervisedTrainer(
    backbone='resnet',
    upsampling='spc', 
    data_train=y_train,
    data_val=y_val,
    data_test=y_test,
    data_train_lr=None, # here you can pass the LR dataset for training with explicit paired samples
    data_val_lr=None, # here you can pass the LR dataset for training with explicit paired samples
    data_test_lr=None, # here you can pass the LR dataset for training with explicit paired samples
    scale=4, 
    time_window=None, 
    static_vars=None,
    predictors_train=[y_z_train],
    predictors_val=[y_z_val],
    predictors_test=[y_z_test],
    interpolation='inter_area',
    patch_size=None, 
    batch_size=60, #changed from 60
    loss='mae',
    epochs=50, 
    steps_per_epoch=None, 
    validation_steps=None, 
    test_steps=None, 
    learning_rate=(1e-3, 1e-4), lr_decay_after=1e4,
    early_stopping=False, patience=6, min_delta=0, 
    save=False, 
    save_path=None,
    show_plot=True, verbose=True, 
    device='CPU',
    **ARCH_PARAMS)
trainer.run()
# Out:
# List of devices:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# Number of devices: 1
# Global batch size: 60
# --------------------------------------------------------------------------------
# Starting time: 2025-01-06 14:36:49
# --------------------------------------------------------------------------------
# Model: "resnet_spc"
# ______________________________________________________________________________________________________________________________________________________
#  Layer (type)                                Output Shape                                 Param #        Connected to
# ======================================================================================================================================================
#  input_1 (InputLayer)                        [(None, None, None, 2)]                      0              []
#
#  conv2d (Conv2D)                             (None, None, None, 8)                        152            ['input_1[0][0]']
#
#  ResidualBlock1 (ResidualBlock)              (None, None, None, 8)                        1168           ['conv2d[0][0]']
#
#  ResidualBlock2 (ResidualBlock)              (None, None, None, 16)                       3632           ['ResidualBlock1[0][0]']
#
#  ResidualBlock3 (ResidualBlock)              (None, None, None, 24)                       9096           ['ResidualBlock2[0][0]']
#
#  ResidualBlock4 (ResidualBlock)              (None, None, None, 32)                       16992          ['ResidualBlock3[0][0]']
#
#  ResidualBlock5 (ResidualBlock)              (None, None, None, 40)                       27320          ['ResidualBlock4[0][0]']
#
#  ResidualBlock6 (ResidualBlock)              (None, None, None, 48)                       40080          ['ResidualBlock5[0][0]']
#
#  ResidualBlock7 (ResidualBlock)              (None, None, None, 56)                       55272          ['ResidualBlock6[0][0]']
#
#  ResidualBlock8 (ResidualBlock)              (None, None, None, 64)                       72896          ['ResidualBlock7[0][0]']
#
#  conv2d_24 (Conv2D)                          (None, None, None, 64)                       36928          ['ResidualBlock8[0][0]']
#
#  transition_block (TransitionBlock)          (None, None, None, 64)                       576            ['conv2d[0][0]']
#
#  lambda (Lambda)                             (None, None, None, 64)                       0              ['conv2d_24[0][0]']
#
#  add (Add)                                   (None, None, None, 64)                       0              ['transition_block[0][0]',
#                                                                                                           'lambda[0][0]']
#
#  SubpixelConvolution (SubpixelConvolutionBl  (None, None, None, 64)                       147712         ['add[0][0]']
#  ock)
#
#  TransitionLast (TransitionBlock)            (None, None, None, 8)                        520            ['SubpixelConvolution[0][0]']
#
#  conv_block (ConvBlock)                      (None, None, None, 8)                        1210           ['TransitionLast[0][0]']
#
#  conv_block_1 (ConvBlock)                    (None, None, None, 1)                        83             ['conv_block[0][0]']
#
# ======================================================================================================================================================
# Total params: 413637 (1.58 MB)
# Trainable params: 413637 (1.58 MB)
# Non-trainable params: 0 (0.00 Byte)
# ______________________________________________________________________________________________________________________________________________________
# Epoch 1/50
# 25/25 [==============================] - 32s 1s/step - loss: 0.5094 - val_loss: 0.2122
# Epoch 2/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.1586 - val_loss: 0.1472
# Epoch 3/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.1191 - val_loss: 0.1247
# Epoch 4/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.1026 - val_loss: 0.1084
# Epoch 5/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.0984 - val_loss: 0.1017
# Epoch 6/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.0876 - val_loss: 0.0910
# Epoch 7/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.0904 - val_loss: 0.0938
# Epoch 8/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.0912 - val_loss: 0.0954
# Epoch 9/50
# 25/25 [==============================] - 26s 1s/step - loss: 0.0833 - val_loss: 0.0795
# Epoch 10/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.0772 - val_loss: 0.0962
# Epoch 11/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.0772 - val_loss: 0.0943
# Epoch 12/50
# 25/25 [==============================] - 26s 1s/step - loss: 0.0710 - val_loss: 0.0708
# Epoch 13/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.0660 - val_loss: 0.0695
# Epoch 14/50
# 25/25 [==============================] - 26s 1s/step - loss: 0.0649 - val_loss: 0.0748
# Epoch 15/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.0705 - val_loss: 0.0674
# Epoch 16/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.0608 - val_loss: 0.0649
# Epoch 17/50
# 25/25 [==============================] - 26s 1s/step - loss: 0.0585 - val_loss: 0.0613
# Epoch 18/50
# 25/25 [==============================] - 26s 1s/step - loss: 0.0630 - val_loss: 0.0879
# Epoch 19/50
# 25/25 [==============================] - 26s 1s/step - loss: 0.0618 - val_loss: 0.0745
# Epoch 20/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.0661 - val_loss: 0.0769
# Epoch 21/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.0601 - val_loss: 0.0605
# Epoch 22/50
# 25/25 [==============================] - 26s 1s/step - loss: 0.0553 - val_loss: 0.0579
# Epoch 23/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.0527 - val_loss: 0.0562
# Epoch 24/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.0586 - val_loss: 0.0597
# Epoch 25/50
# 25/25 [==============================] - 26s 1s/step - loss: 0.0625 - val_loss: 0.0765
# Epoch 26/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.0595 - val_loss: 0.0613
# Epoch 27/50
# 25/25 [==============================] - 26s 1s/step - loss: 0.0538 - val_loss: 0.0566
# Epoch 28/50
# 25/25 [==============================] - 26s 1s/step - loss: 0.0583 - val_loss: 0.0555
# Epoch 29/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.0551 - val_loss: 0.0574
# Epoch 30/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.0514 - val_loss: 0.0586
# Epoch 31/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.0520 - val_loss: 0.0808
# Epoch 32/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.0563 - val_loss: 0.0804
# Epoch 33/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.0566 - val_loss: 0.0559
# Epoch 34/50
# 25/25 [==============================] - 26s 1s/step - loss: 0.0474 - val_loss: 0.0531
# Epoch 35/50
# 25/25 [==============================] - 26s 1s/step - loss: 0.0485 - val_loss: 0.0665
# Epoch 36/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.0598 - val_loss: 0.0517
# Epoch 37/50
# 25/25 [==============================] - 26s 1s/step - loss: 0.0485 - val_loss: 0.0673
# Epoch 38/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.0509 - val_loss: 0.0571
# Epoch 39/50
# 25/25 [==============================] - 26s 1s/step - loss: 0.0527 - val_loss: 0.0598
# Epoch 40/50
# 25/25 [==============================] - 26s 1s/step - loss: 0.0487 - val_loss: 0.0492
# Epoch 41/50
# 25/25 [==============================] - 26s 1s/step - loss: 0.0506 - val_loss: 0.0526
# Epoch 42/50
# 25/25 [==============================] - 26s 1s/step - loss: 0.0578 - val_loss: 0.0582
# Epoch 43/50
# 25/25 [==============================] - 26s 1s/step - loss: 0.0541 - val_loss: 0.0494
# Epoch 44/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.0495 - val_loss: 0.0590
# Epoch 45/50
# 25/25 [==============================] - 26s 1s/step - loss: 0.0467 - val_loss: 0.0488
# Epoch 46/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.0426 - val_loss: 0.0471
# Epoch 47/50
# 25/25 [==============================] - 26s 1s/step - loss: 0.0436 - val_loss: 0.0474
# Epoch 48/50
# 25/25 [==============================] - 26s 1s/step - loss: 0.0541 - val_loss: 0.0609
# Epoch 49/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.0519 - val_loss: 0.0498
# Epoch 50/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.0458 - val_loss: 0.0495
# 14/14 [==============================] - 3s 197ms/step - loss: 0.0494
#
# Score on the test set: 0.04935549199581146
# --------------------------------------------------------------------------------
# Final running time: 0:22:19.295363
# --------------------------------------------------------------------------------

# %%
pred = dds.Predictor(
    trainer, 
    y_test, 
    scale=4, 
    array_in_hr=False,
    static_vars=None, 
    predictors=[y_z_test], 
    time_window=None,
    interpolation='inter_area', 
    batch_size=64,
    scaler=T2_scaler_train,
    save_path=None,
    save_fname=None,
    return_lr=True,
    device='CPU')

unscaled_y_pred, coarsened_array = pred.run()
# Out:
# --------------------------------------------------------------------------------
# Starting time: 2025-01-06 15:56:10
# --------------------------------------------------------------------------------
# 14/14 [==============================] - 45s 3s/step
# --------------------------------------------------------------------------------
# Final running time: 0:00:47.464150
# --------------------------------------------------------------------------------

# %%
pred1 = dds.Predictor(
    trainer, 
    x_test, 
    scale=4, 
    array_in_hr=False,
    static_vars=None, 
    predictors=[x_z_test], 
    time_window=None,
    interpolation='inter_area', 
    batch_size=4,
    scaler=T2_scaler_train,
    save_path=None,
    save_fname=None,
    return_lr=True,
    device='CPU')

unscaled_x_pred, coarsened_array1 = pred1.run()
# Out:
# --------------------------------------------------------------------------------
# Starting time: 2025-01-06 15:54:54
# --------------------------------------------------------------------------------
# 113/113 [==============================] - 2s 19ms/step
# --------------------------------------------------------------------------------
# Final running time: 0:00:02.275794
# --------------------------------------------------------------------------------

# %%
ind = 0
ecv.plot((coarsened_array[ind][:,:,0], coarsened_array[ind][:,:,1]), subplot_titles=('t2m', 'surface pressure (predictor)'),)

# %%
unscaled_y_test = T2_scaler_train.inverse_transform(y_test)

# %%
ecv.plot((unscaled_y_test[1].values, unscaled_y_pred[1]), subplot_titles=('groundtruth t2m', 'downscaled t2m'))

# %%
unscaled_x_test = T2_scaler_train.inverse_transform(x_test)
ecv.plot((unscaled_x_test[1].values, unscaled_x_pred[1]), subplot_titles=('original t2m (NAM)', 'downscaled t2m'))

# %%
ecv.plot((unscaled_y_test[1].values, unscaled_x_pred[1]), subplot_titles=('ground truth t2m (uWRF)', 'downscaled t2m'))

# %%
ind = 0
ecv.plot((coarsened_array1[ind][:,:,0], coarsened_array1[ind][:,:,1]))
