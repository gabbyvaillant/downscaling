# %%
#testing



import xarray as xr

uwrf = xr.open_dataset('/D4/data/gvaillant/uwrf/01/01/d02_files/wrfout_d02_2019-01-01_00:00:00')


uwrf
# Out:
# <xarray.Dataset>
# Dimensions:                (Time: 1, south_north: 120, west_east: 120, bottom_top: 50, bottom_top_stag: 51, soil_layers_stag: 4, west_east_stag: 121, south_north_stag: 121, urban_layers_stag: 5400)
# Coordinates:
#     XLAT                   (Time, south_north, west_east) float32 ...
#     XLONG                  (Time, south_north, west_east) float32 ...
#     XTIME                  (Time) datetime64[ns] ...
#     XLAT_U                 (Time, south_north, west_east_stag) float32 ...
#     XLONG_U                (Time, south_north, west_east_stag) float32 ...
#     XLAT_V                 (Time, south_north_stag, west_east) float32 ...
#     XLONG_V                (Time, south_north_stag, west_east) float32 ...
# Dimensions without coordinates: Time, south_north, west_east, bottom_top, bottom_top_stag, soil_layers_stag, west_east_stag, south_north_stag, urban_layers_stag
# Data variables: (12/162)
#     Times                  (Time) |S19 ...
# ...

# %%
nam = xr.open_dataset('/D4/data/gvaillant/NAM-2019-netcdf/01/domnys-nam_218_20190101_0000_000.nc')

nam
# Out:
# <xarray.Dataset>
# Dimensions:                                           (y: 67, x: 71, time: 1)
# Coordinates:
#   * y                                                 (y) float64 0.0 ... 8.0...
#   * x                                                 (x) float64 0.0 ... 8.5...
#     latitude                                          (y, x) float64 ...
#     longitude                                         (y, x) float64 ...
#   * time                                              (time) datetime64[ns] 2...
# Data variables: (12/445)
#     PRMSL_meansealevel                                (time, y, x) float32 ...
#     REFD_1hybridlevel                                 (time, y, x) float32 ...
#     REFC_entireatmosphere_consideredasasinglelayer_   (time, y, x) float32 ...
#     VIS_surface                                       (time, y, x) float32 ...
#     VIS_cloudtop                                      (time, y, x) float32 ...
# ...

# %%
#SWDOWN results uWRF

import xarray as xr

uwrf = xr.open_dataset('/D4/data/gvaillant/uwrf-cleaned/uwrf_cleaned_05_SWDOWN.nc')

uwrf
# Out:
# <xarray.Dataset>
# Dimensions:    (Time: 631, south_north: 120, west_east: 120)
# Coordinates:
#     latitude   (Time, south_north, west_east) float32 ...
#     longitude  (Time, south_north, west_east) float32 ...
#     time       (Time) datetime64[ns] ...
# Dimensions without coordinates: Time, south_north, west_east
# Data variables:
#     SWDOWN     (Time, south_north, west_east) float32 ...
# Attributes: (12/119)
#     TITLE:                            OUTPUT FROM WRF V3.9 MODEL
#     START_DATE:                      2019-05-01_00:00:00
#     SIMULATION_START_DATE:           2019-05-01_00:00:00
#     WEST-EAST_GRID_DIMENSION:        121
#     SOUTH-NORTH_GRID_DIMENSION:      121
#     BOTTOM-TOP_GRID_DIMENSION:       51
#     ...                              ...
#     ISLAKE:                          -1
#     ISICE:                           15
#     ISURBAN:                         13
#     ISOILWATER:                      14
#     HYBRID_OPT:                      -1
# ...

# %%
#SWDOWN results NAM

nam = xr.open_dataset('/D4/data/gvaillant/NAM-cleaned/nam_cleaned_01_DSWRF_surface.nc')

nam
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 739, y: 38, x: 36)
# Coordinates:
#   * y              (y) float64 7.315e+04 8.534e+04 ... 5.12e+05 5.242e+05
#   * x              (x) float64 2.926e+05 3.048e+05 ... 7.071e+05 7.193e+05
#     latitude       (y, x) float64 ...
#     longitude      (y, x) float64 ...
#   * time           (time) datetime64[ns] 2019-01-01 ... 2019-02-03T12:00:00
# Data variables:
#     DSWRF_surface  (time, y, x) float32 ...
# Attributes:
#     Conventions:          CF-1.0
#     History:              created by wgrib2
#     GRIB2_grid_template:  30

# %%
nam = xr.open_dataset('/D4/data/gvaillant/NAM-cleaned/WS/nam_cleaned_01_WS.nc')

nam
# Out:
# <xarray.Dataset>
# Dimensions:              (time: 746, y: 38, x: 36)
# Coordinates:
#   * y                    (y) float64 7.315e+04 8.534e+04 ... 5.12e+05 5.242e+05
#   * x                    (x) float64 2.926e+05 3.048e+05 ... 7.071e+05 7.193e+05
#     latitude             (y, x) float64 ...
#     longitude            (y, x) float64 ...
#   * time                 (time) datetime64[ns] 2019-01-01 ... 2019-02-03T12:0...
# Data variables:
#     VGRD_10maboveground  (time, y, x) float32 ...
#     UGRD_10maboveground  (time, y, x) float32 ...
#     PRES_surface         (time, y, x) float32 ...
# Attributes:
#     Conventions:          CF-1.0
#     History:              created by wgrib2
#     GRIB2_grid_template:  30
