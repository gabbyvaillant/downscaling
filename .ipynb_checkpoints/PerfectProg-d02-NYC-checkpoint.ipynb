# %% [markdown]
# # Applying PerfectProg training to uWRF d02 NYC
# # Scale by 4 (3km x4 = 12 km)
#
# Then once we have the dimensions all set (time, latitude, longitude) we need to spatially filter it is divisble by 4.

# %%
import xarray as xr
import numpy as np
import ecubevis as ecv
import scipy as sp
import netCDF4 as nc
import dl4ds as dds
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras import models
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# 2025-01-07 14:49:20.141379: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-07 14:49:20.184433: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-07 14:49:20.185717: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-07 14:49:21.708402: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# !python --version
# Out:
# Python 3.8.18

# %%
#FILES CONTAINING ALL PREPROCESSED DATA NEEDED FOR MODEL:
uwrf_train = xr.open_dataset('/D4/data/gvaillant/prep-uwrf/d02/pred-NYC-split/train/uWRF_final_01-02.nc')
uwrf_val = xr.open_dataset('/D4/data/gvaillant/prep-uwrf/d02/pred-NYC-split/val/uWRF_final_03.nc')
uwrf_test = xr.open_dataset('/D4/data/gvaillant/prep-uwrf/d02/pred-NYC-split/test/uWRF_final_03.nc')

nam_train = xr.open_dataset('/home/gvaillant1/aligned-NYC-data/aligned_nam_train_data.nc')
nam_val = xr.open_dataset('/home/gvaillant1/aligned-NYC-data/aligned_nam_test_data.nc')
nam_test = xr.open_dataset('/home/gvaillant1/aligned-NYC-data/aligned_nam_val_data.nc')

# %%
#High resolution (uWRF) data
T2_hr_train = uwrf_train.T2
T2_hr_val = uwrf_val.T2
T2_hr_test = uwrf_test.T2

PRES_hr_train = uwrf_train.PSFC
PRES_hr_val = uwrf_val.PSFC
PRES_hr_test = uwrf_test.PSFC

#--------------------------
#Low resolution (NAM) data
T2_lr_train = nam_train.T2
T2_lr_val = nam_val.T2
T2_lr_test = nam_test.T2

PRES_lr_train = nam_train.PSFC
PRES_lr_val = nam_val.PSFC
PRES_lr_test = nam_test.PSFC

# %%
T2_scaler_train = dds.StandardScaler(axis=None)
T2_scaler_train.fit(T2_hr_train)  

PRES_scaler_train = dds.StandardScaler(axis=None)
PRES_scaler_train.fit(PRES_hr_train)
#----------------------------------------------
#High resolution (uWRF):
y_train = T2_scaler_train.transform(T2_hr_train)
y_val = T2_scaler_train.transform(T2_hr_val)
y_test = T2_scaler_train.transform(T2_hr_test)


y_z_train = PRES_scaler_train.transform(PRES_hr_train)
y_z_val = PRES_scaler_train.transform(PRES_hr_val)
y_z_test = PRES_scaler_train.transform(PRES_hr_test)

#-------------------------------------------------
#Low resolution (NAM)

x_train = T2_scaler_train.transform(T2_lr_train)
x_val = T2_scaler_train.transform(T2_lr_val)
x_test = T2_scaler_train.transform(T2_lr_test)

x_z_train = PRES_scaler_train.transform(PRES_lr_train)
x_z_val = PRES_scaler_train.transform(PRES_lr_val)
x_z_test = PRES_scaler_train.transform(PRES_lr_test)

# %%
y_train = y_train.expand_dims(dim='channel', axis=-1)
y_val = y_val.expand_dims(dim='channel', axis=-1)
y_test = y_test.expand_dims(dim='channel', axis=-1)

y_z_train = y_z_train.expand_dims(dim ='channel', axis=-1)
y_z_val = y_z_val.expand_dims(dim ='channel', axis=-1)
y_z_test = y_z_test.expand_dims(dim ='channel', axis=-1)

#-----------------------------------------------------

x_train = x_train.expand_dims(dim='channel', axis=-1)
x_val = x_val.expand_dims(dim='channel', axis=-1)
x_test = x_test.expand_dims(dim='channel', axis=-1)

x_z_train = x_z_train.expand_dims(dim ='channel', axis=-1)
x_z_val = x_z_val.expand_dims(dim ='channel', axis=-1)
x_z_test = x_z_test.expand_dims(dim ='channel', axis=-1)

# %%
print("T2 hr data shape:")
print(y_train.shape, y_val.shape, y_test.shape)
print("")
print("PRES hr data shape:")
print(y_z_train.shape, y_z_val.shape, y_z_test.shape)
print("")
print("T2 lr data shape:")
print(x_train.shape, x_val.shape, x_test.shape)
print("")
print("PRES lr data shape:")
print(x_z_train.shape, x_z_val.shape, x_z_test.shape)
# Out:
# T2 hr data shape:
# (1537, 20, 20, 1) (812, 20, 20, 1) (812, 20, 20, 1)
#
# PRES hr data shape:
# (1537, 20, 20, 1) (812, 20, 20, 1) (812, 20, 20, 1)
#
# T2 lr data shape:
# (1537, 5, 5, 1) (450, 5, 5, 1) (449, 5, 5, 1)
#
# PRES lr data shape:
# (1537, 5, 5, 1) (450, 5, 5, 1) (449, 5, 5, 1)

# %%
#Check for correct creation of the low-res version of uWRF
#This function is called before training begins. This is just an example to show what is going on:

_ = dds.create_pair_hr_lr(y_train.values[0], None, 'spc', 4, None, None, y_z_train.values[0], None, True, interpolation='inter_area')
# Out:
# HR array: (20, 20, 1), LR array (5, 5, 2)

# %% [markdown]
# # Training Model
#
# There are several types of backbones to try, so here we will implement each one and evaluate which performs best.
#
# * resnet: MAE = 0.09434913098812103
# * densenet: MAE = 0.04823455959558487 **best**
# * convnet: MAE = 0.4711471498012543
# * convnext: MAE = doesn't work

# %%
#Implementing resnet
ARCH_PARAMS = dict(n_filters=8,
                   n_blocks=8,
                   normalization=None,
                   dropout_rate=0.0,
                   dropout_variant='spatial',
                   attention=False,
                   activation='relu',
                   localcon_layer=False)

trainer = dds.SupervisedTrainer(
    backbone='densenet',
    upsampling='spc', 
    data_train=y_train,
    data_val=y_val,
    data_test=y_test,
    data_train_lr=None, # here you can pass the LR dataset for training with explicit paired samples
    data_val_lr=None, # here you can pass the LR dataset for training with explicit paired samples
    data_test_lr=None, # here you can pass the LR dataset for training with explicit paired samples
    scale=4, 
    time_window=None, 
    static_vars=None,
    predictors_train=[y_z_train],
    predictors_val=[y_z_val],
    predictors_test=[y_z_test],
    interpolation='inter_area',
    patch_size=None, 
    batch_size=60, #changed from 60
    loss='mae',
    epochs=50, 
    steps_per_epoch=None, 
    validation_steps=None, 
    test_steps=None, 
    learning_rate=(1e-3, 1e-4), lr_decay_after=1e4,
    early_stopping=False, patience=6, min_delta=0, 
    save=False, 
    save_path=None,
    show_plot=True, verbose=True, 
    device='CPU',
    **ARCH_PARAMS)
trainer.run()
# Out:
# List of devices:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# Number of devices: 1
# Global batch size: 60
# --------------------------------------------------------------------------------
# Starting time: 2025-01-07 14:49:26
# --------------------------------------------------------------------------------
# Model: "densenet_spc"
# ______________________________________________________________________________________________________________________________________________________
#  Layer (type)                                Output Shape                                 Param #        Connected to
# ======================================================================================================================================================
#  input_1 (InputLayer)                        [(None, None, None, 2)]                      0              []
#
#  conv2d (Conv2D)                             (None, None, None, 8)                        152            ['input_1[0][0]']
#
#  DenseBlock1 (DenseBlock)                    (None, None, None, 16)                       2600           ['conv2d[0][0]']
#
#  Transition1 (TransitionBlock)               (None, None, None, 8)                        136            ['DenseBlock1[0][0]']
#
#  DenseBlock2 (DenseBlock)                    (None, None, None, 24)                       9808           ['Transition1[0][0]']
#
#  Transition2 (TransitionBlock)               (None, None, None, 12)                       300            ['DenseBlock2[0][0]']
#
#  DenseBlock3 (DenseBlock)                    (None, None, None, 36)                       22008          ['Transition2[0][0]']
#
#  Transition3 (TransitionBlock)               (None, None, None, 18)                       666            ['DenseBlock3[0][0]']
#
#  DenseBlock4 (DenseBlock)                    (None, None, None, 50)                       39328          ['Transition3[0][0]']
#
#  Transition4 (TransitionBlock)               (None, None, None, 25)                       1275           ['DenseBlock4[0][0]']
#
#  DenseBlock5 (DenseBlock)                    (None, None, None, 65)                       61800          ['Transition4[0][0]']
#
#  Transition5 (TransitionBlock)               (None, None, None, 32)                       2112           ['DenseBlock5[0][0]']
#
#  DenseBlock6 (DenseBlock)                    (None, None, None, 80)                       89328          ['Transition5[0][0]']
#
#  Transition6 (TransitionBlock)               (None, None, None, 40)                       3240           ['DenseBlock6[0][0]']
#
#  DenseBlock7 (DenseBlock)                    (None, None, None, 96)                       122136         ['Transition6[0][0]']
#
#  Transition7 (TransitionBlock)               (None, None, None, 48)                       4656           ['DenseBlock7[0][0]']
#
#  DenseBlock8 (DenseBlock)                    (None, None, None, 112)                      160064         ['Transition7[0][0]']
#
#  Transition8 (TransitionBlock)               (None, None, None, 56)                       6328           ['DenseBlock8[0][0]']
#
#  conv2d_41 (Conv2D)                          (None, None, None, 64)                       32320          ['Transition8[0][0]']
#
#  lambda (Lambda)                             (None, None, None, 64)                       0              ['conv2d_41[0][0]']
#
#  concatenate_8 (Concatenate)                 (None, None, None, 72)                       0              ['conv2d[0][0]',
#                                                                                                           'lambda[0][0]']
#
#  TransitionBackboneLast (TransitionBlock)    (None, None, None, 64)                       4672           ['concatenate_8[0][0]']
#
#  SubpixelConvolution (SubpixelConvolutionBl  (None, None, None, 64)                       147712         ['TransitionBackboneLast[0][0]']
#  ock)
#
#  TransitionLast (TransitionBlock)            (None, None, None, 8)                        520            ['SubpixelConvolution[0][0]']
#
#  conv_block (ConvBlock)                      (None, None, None, 8)                        1210           ['TransitionLast[0][0]']
#
#  conv_block_1 (ConvBlock)                    (None, None, None, 1)                        83             ['conv_block[0][0]']
#
# ======================================================================================================================================================
# Total params: 712454 (2.72 MB)
# Trainable params: 712454 (2.72 MB)
# Non-trainable params: 0 (0.00 Byte)
# ______________________________________________________________________________________________________________________________________________________
# Epoch 1/50
# 25/25 [==============================] - 6s 74ms/step - loss: 0.4087 - val_loss: 0.2295
# Epoch 2/50
# 25/25 [==============================] - 1s 53ms/step - loss: 0.1839 - val_loss: 0.1141
# Epoch 3/50
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1100 - val_loss: 0.0879
# Epoch 4/50
# 25/25 [==============================] - 2s 64ms/step - loss: 0.0936 - val_loss: 0.0738
# Epoch 5/50
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0788 - val_loss: 0.0648
# Epoch 6/50
# 25/25 [==============================] - 1s 55ms/step - loss: 0.0678 - val_loss: 0.0698
# Epoch 7/50
# 25/25 [==============================] - 1s 50ms/step - loss: 0.0715 - val_loss: 0.0568
# Epoch 8/50
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0582 - val_loss: 0.0504
# Epoch 9/50
# 25/25 [==============================] - 1s 47ms/step - loss: 0.0646 - val_loss: 0.0571
# Epoch 10/50
# 25/25 [==============================] - 1s 50ms/step - loss: 0.0569 - val_loss: 0.0434
# Epoch 11/50
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0545 - val_loss: 0.0649
# Epoch 12/50
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0504 - val_loss: 0.0382
# Epoch 13/50
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0438 - val_loss: 0.0394
# Epoch 14/50
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0469 - val_loss: 0.0349
# Epoch 15/50
# 25/25 [==============================] - 1s 51ms/step - loss: 0.0477 - val_loss: 0.0360
# Epoch 16/50
# 25/25 [==============================] - 1s 47ms/step - loss: 0.0463 - val_loss: 0.0360
# Epoch 17/50
# 25/25 [==============================] - 1s 46ms/step - loss: 0.0446 - val_loss: 0.0346
# Epoch 18/50
# 25/25 [==============================] - 1s 47ms/step - loss: 0.0437 - val_loss: 0.0313
# Epoch 19/50
# 25/25 [==============================] - 1s 46ms/step - loss: 0.0391 - val_loss: 0.0372
# Epoch 20/50
# 25/25 [==============================] - 1s 46ms/step - loss: 0.0375 - val_loss: 0.0359
# Epoch 21/50
# 25/25 [==============================] - 1s 46ms/step - loss: 0.0389 - val_loss: 0.0403
# Epoch 22/50
# 25/25 [==============================] - 1s 47ms/step - loss: 0.0471 - val_loss: 0.0420
# Epoch 23/50
# 25/25 [==============================] - 1s 47ms/step - loss: 0.0482 - val_loss: 0.0597
# Epoch 24/50
# 25/25 [==============================] - 1s 45ms/step - loss: 0.0432 - val_loss: 0.0299
# Epoch 25/50
# 25/25 [==============================] - 1s 47ms/step - loss: 0.0375 - val_loss: 0.0503
# Epoch 26/50
# 25/25 [==============================] - 1s 46ms/step - loss: 0.0430 - val_loss: 0.0401
# Epoch 27/50
# 25/25 [==============================] - 1s 49ms/step - loss: 0.0427 - val_loss: 0.0334
# Epoch 28/50
# 25/25 [==============================] - 1s 46ms/step - loss: 0.0364 - val_loss: 0.0301
# Epoch 29/50
# 25/25 [==============================] - 1s 47ms/step - loss: 0.0354 - val_loss: 0.0277
# Epoch 30/50
# 25/25 [==============================] - 1s 47ms/step - loss: 0.0330 - val_loss: 0.0296
# Epoch 31/50
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0346 - val_loss: 0.0402
# Epoch 32/50
# 25/25 [==============================] - 1s 47ms/step - loss: 0.0396 - val_loss: 0.0291
# Epoch 33/50
# 25/25 [==============================] - 1s 46ms/step - loss: 0.0369 - val_loss: 0.0283
# Epoch 34/50
# 25/25 [==============================] - 1s 47ms/step - loss: 0.0320 - val_loss: 0.0269
# Epoch 35/50
# 25/25 [==============================] - 1s 46ms/step - loss: 0.0311 - val_loss: 0.0319
# Epoch 36/50
# 25/25 [==============================] - 1s 46ms/step - loss: 0.0400 - val_loss: 0.0342
# Epoch 37/50
# 25/25 [==============================] - 1s 48ms/step - loss: 0.0341 - val_loss: 0.0267
# Epoch 38/50
# 25/25 [==============================] - 1s 46ms/step - loss: 0.0297 - val_loss: 0.0249
# Epoch 39/50
# 25/25 [==============================] - 1s 46ms/step - loss: 0.0287 - val_loss: 0.0255
# Epoch 40/50
# 25/25 [==============================] - 1s 47ms/step - loss: 0.0364 - val_loss: 0.0414
# Epoch 41/50
# 25/25 [==============================] - 1s 47ms/step - loss: 0.0356 - val_loss: 0.0326
# Epoch 42/50
# 25/25 [==============================] - 1s 46ms/step - loss: 0.0349 - val_loss: 0.0293
# Epoch 43/50
# 25/25 [==============================] - 1s 47ms/step - loss: 0.0354 - val_loss: 0.0375
# Epoch 44/50
# 25/25 [==============================] - 1s 46ms/step - loss: 0.0386 - val_loss: 0.0406
# Epoch 45/50
# 25/25 [==============================] - 1s 47ms/step - loss: 0.0436 - val_loss: 0.0318
# Epoch 46/50
# 25/25 [==============================] - 1s 46ms/step - loss: 0.0310 - val_loss: 0.0270
# Epoch 47/50
# 25/25 [==============================] - 1s 47ms/step - loss: 0.0345 - val_loss: 0.0423
# Epoch 48/50
# 25/25 [==============================] - 1s 47ms/step - loss: 0.0378 - val_loss: 0.0303
# Epoch 49/50
# 25/25 [==============================] - 1s 47ms/step - loss: 0.0325 - val_loss: 0.0244
# Epoch 50/50
# 25/25 [==============================] - 1s 47ms/step - loss: 0.0278 - val_loss: 0.0233
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0230
#
# Score on the test set: 0.023029955103993416
# --------------------------------------------------------------------------------
# Final running time: 0:01:07.271959
# --------------------------------------------------------------------------------

# %%
pred = dds.Predictor(
    trainer, 
    y_test, 
    scale=4, 
    array_in_hr=True,
    static_vars=None, 
    predictors=[y_z_test], 
    time_window=None,
    interpolation='inter_area', 
    batch_size=64,
    scaler=T2_scaler_train,
    save_path=None,
    save_fname=None,
    return_lr=True,
    device='CPU')

unscaled_y_pred, coarsened_array = pred.run()
# Out:
# --------------------------------------------------------------------------------
# Starting time: 2025-01-07 14:50:40
# --------------------------------------------------------------------------------
# 13/13 [==============================] - 0s 14ms/step
# --------------------------------------------------------------------------------
# Final running time: 0:00:00.277960
# --------------------------------------------------------------------------------

# %%
pred1 = dds.Predictor(
    trainer, 
    x_test, 
    scale=4, 
    array_in_hr=False,
    static_vars=None, 
    predictors=[x_z_test], 
    time_window=None,
    interpolation='inter_area', 
    batch_size=4,
    scaler=T2_scaler_train,
    save_path=None,
    save_fname=None,
    return_lr=True,
    device='CPU')

unscaled_x_pred, coarsened_array1 = pred1.run()
# Out:
# --------------------------------------------------------------------------------
# Starting time: 2025-01-07 14:50:42
# --------------------------------------------------------------------------------
# 113/113 [==============================] - 0s 4ms/step
# --------------------------------------------------------------------------------
# Final running time: 0:00:00.574528
# --------------------------------------------------------------------------------

# %%
ind = 0
ecv.plot((coarsened_array[ind][:,:,0], coarsened_array[ind][:,:,1]), subplot_titles=('t2m', 'surface pressure (predictor)'),)

# %% [markdown]
# # Compare training results with the ground truth data (uWRF)

# %%
unscaled_y_test = T2_scaler_train.inverse_transform(y_test)
ecv.plot((unscaled_y_test[0].values, unscaled_y_pred[0]), subplot_titles=('groundtruth t2m', 'downscaled t2m'))

# %% [markdown]
# # Compare results with the original NAM data

# %%
unscaled_x_test = T2_scaler_train.inverse_transform(x_test)
ecv.plot((unscaled_x_test[0].values, unscaled_x_pred[0]), subplot_titles=('original t2m (NAM)', 'downscaled t2m'))

# %% [markdown]
# # Compare results with ground truth data (uWRF)

# %%
ecv.plot((unscaled_y_test[0].values, unscaled_x_pred[0]), subplot_titles=('ground truth t2m (uWRF)', 'downscaled t2m'))

# %% [markdown]
# # Loss

# %%
#These are the same.................................... this is wrong
mae = dds.losses.mae(unscaled_y_test[0], unscaled_y_pred[0])
print(f"MAE for training: {mae}")

mse = dds.losses.mse(unscaled_y_test[0], unscaled_y_pred[0])
print(f"MSE for training: {mse}")
print("")
mae_pred = dds.losses.mae(unscaled_y_test[0], unscaled_x_pred[0])
print(f"MAE on NAM: {mae_pred}")
mse_pred = dds.losses.mse(unscaled_y_test[0], unscaled_x_pred[0])
print(f"MSE on NAM: {mse_pred}")
# Out:
# MAE for training: 0.07116477936506271
# MSE for training: 0.010013705119490623
#
# MAE on NAM: 0.07116355001926422
# MSE on NAM: 0.010013486258685589
