# %%
import xarray as xr
import numpy as np
import ecubevis as ecv
import scipy as sp
import netCDF4 as nc
import dl4ds as dds
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras import models
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# 2025-01-14 13:17:53.912576: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-14 13:17:53.954744: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-14 13:17:53.956117: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-14 13:17:55.481767: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# !python --version
# Out:
# Python 3.8.18

# %%
#FILES CONTAINING ALL PREPROCESSED DATA NEEDED FOR MODEL:
uwrf_train = xr.open_dataset('/D4/data/gvaillant/prep-uwrf/d02/tendays-combined/train/uWRF_final_2019-01-10_to_2019-01-18.nc')
uwrf_val = xr.open_dataset('/D4/data/gvaillant/prep-uwrf/d02/tendays-combined/val/uWRF_final_2019-01-19.nc')
uwrf_test = xr.open_dataset('/D4/data/gvaillant/prep-uwrf/d02/tendays-combined/test/uWRF_final_2019-01-20.nc')

nam_train = xr.open_dataset('/home/gvaillant1/aligned-NYC-tendays-data/aligned_nam_train_data.nc')
nam_val = xr.open_dataset('/home/gvaillant1/aligned-NYC-tendays-data/aligned_nam_val_data.nc')
nam_test = xr.open_dataset('/home/gvaillant1/aligned-NYC-tendays-data/aligned_nam_test_data.nc')

# %%
#High resolution (uWRF) data
T2_hr_train = uwrf_train.T2
T2_hr_val = uwrf_val.T2
T2_hr_test = uwrf_test.T2

PRES_hr_train = uwrf_train.PSFC
PRES_hr_val = uwrf_val.PSFC
PRES_hr_test = uwrf_test.PSFC

#--------------------------
#Low resolution (NAM) data
T2_lr_train = nam_train.T2
T2_lr_val = nam_val.T2
T2_lr_test = nam_test.T2

PRES_lr_train = nam_train.PSFC
PRES_lr_val = nam_val.PSFC
PRES_lr_test = nam_test.PSFC

# %%
T2_scaler_train = dds.StandardScaler(axis=None)
T2_scaler_train.fit(T2_hr_train)  

PRES_scaler_train = dds.StandardScaler(axis=None)
PRES_scaler_train.fit(PRES_hr_train)
#----------------------------------------------
#High resolution (uWRF):
y_train = T2_scaler_train.transform(T2_hr_train)
y_val = T2_scaler_train.transform(T2_hr_val)
y_test = T2_scaler_train.transform(T2_hr_test)


y_z_train = PRES_scaler_train.transform(PRES_hr_train)
y_z_val = PRES_scaler_train.transform(PRES_hr_val)
y_z_test = PRES_scaler_train.transform(PRES_hr_test)

#-------------------------------------------------
#Low resolution (NAM)

x_train = T2_scaler_train.transform(T2_lr_train)
x_val = T2_scaler_train.transform(T2_lr_val)
x_test = T2_scaler_train.transform(T2_lr_test)

x_z_train = PRES_scaler_train.transform(PRES_lr_train)
x_z_val = PRES_scaler_train.transform(PRES_lr_val)
x_z_test = PRES_scaler_train.transform(PRES_lr_test)

# %%
ecv.plot((x_train[0].values, y_train[0]), subplot_titles=('t2m coarsened', 't2m highres'))

# %%
ecv.plot((x_z_train[0].values, y_z_train[0]), subplot_titles=('surface pressure coarsened', 'surface pressure highres'))

# %%
y_train = y_train.expand_dims(dim='channel', axis=-1)
y_val = y_val.expand_dims(dim='channel', axis=-1)
y_test = y_test.expand_dims(dim='channel', axis=-1)

y_z_train = y_z_train.expand_dims(dim ='channel', axis=-1)
y_z_val = y_z_val.expand_dims(dim ='channel', axis=-1)
y_z_test = y_z_test.expand_dims(dim ='channel', axis=-1)

#-----------------------------------------------------

x_train = x_train.expand_dims(dim='channel', axis=-1)
x_val = x_val.expand_dims(dim='channel', axis=-1)
x_test = x_test.expand_dims(dim='channel', axis=-1)

x_z_train = x_z_train.expand_dims(dim ='channel', axis=-1)
x_z_val = x_z_val.expand_dims(dim ='channel', axis=-1)
x_z_test = x_z_test.expand_dims(dim ='channel', axis=-1)

# %%
print("T2 hr data shape:")
print(y_train.shape, y_val.shape, y_test.shape)
print("")
print("PRES hr data shape:")
print(y_z_train.shape, y_z_val.shape, y_z_test.shape)
print("")
print("T2 lr data shape:")
print(x_train.shape, x_val.shape, x_test.shape)
print("")
print("PRES lr data shape:")
print(x_z_train.shape, x_z_val.shape, x_z_test.shape)
# Out:
# T2 hr data shape:
# (72, 20, 20, 1) (8, 20, 20, 1) (8, 20, 20, 1)
#
# PRES hr data shape:
# (72, 20, 20, 1) (8, 20, 20, 1) (8, 20, 20, 1)
#
# T2 lr data shape:
# (72, 5, 5, 1) (8, 5, 5, 1) (8, 5, 5, 1)
#
# PRES lr data shape:
# (72, 5, 5, 1) (8, 5, 5, 1) (8, 5, 5, 1)

# %%
#Check for correct creation of the low-res version of uWRF
#This function is called before training begins. This is just an example to show what is going on:

_ = dds.create_pair_hr_lr(y_train.values[0], None, 'spc', 4, None, None, y_z_train.values[0], None, True, interpolation='inter_area')
# Out:
# HR array: (20, 20, 1), LR array (5, 5, 2)

# %%
#Need to tune hyperparameters
#Model is currently overfitting
ARCH_PARAMS = dict(n_filters=20,
                   n_blocks=6,
                   normalization='bn', #Batch normalization
                   dropout_rate=0.5,
                   dropout_variant='spatial',
                   attention=False,
                   activation='relu',
                   localcon_layer=False) #when set to true.. it works

trainer = dds.SupervisedTrainer(
    backbone='densenet',
    upsampling='spc', 
    data_train=y_train,
    data_val=y_val,
    data_test=y_test,
    data_train_lr=None, # here you can pass the LR dataset for training with explicit paired samples
    data_val_lr=None, # here you can pass the LR dataset for training with explicit paired samples
    data_test_lr=None, # here you can pass the LR dataset for training with explicit paired samples
    scale=4, 
    time_window=None, 
    static_vars=None,
    predictors_train=[y_z_train],
    predictors_val=[y_z_val],
    predictors_test=[y_z_test],
    interpolation='inter_area',
    patch_size=None, 
    batch_size=1, #changed from 60
    loss='mae',
    epochs=50, 
    steps_per_epoch=None, 
    validation_steps=None, 
    test_steps=None, 
    learning_rate=(1e-3, 1e-4), lr_decay_after=1e4,
    early_stopping=False, patience=6, min_delta=0, 
    save=False, 
    save_path=None,
    show_plot=True, verbose=True, 
    device='CPU',
    **ARCH_PARAMS)
trainer.run()
# Out:
# List of devices:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# Number of devices: 1
# Global batch size: 1
# --------------------------------------------------------------------------------
# Starting time: 2025-01-14 16:28:35
# --------------------------------------------------------------------------------
# Model: "densenet_spc"
# ______________________________________________________________________________________________________________________________________________________
#  Layer (type)                                Output Shape                                 Param #        Connected to
# ======================================================================================================================================================
#  input_4 (InputLayer)                        [(None, None, None, 2)]                      0              []
#
#  conv2d_129 (Conv2D)                         (None, None, None, 20)                       380            ['input_4[0][0]']
#
#  DenseBlock1 (DenseBlock)                    (None, None, None, 40)                       16500          ['conv2d_129[0][0]']
#
#  Transition1 (TransitionBlock)               (None, None, None, 20)                       820            ['DenseBlock1[0][0]']
#
#  DenseBlock2 (DenseBlock)                    (None, None, None, 60)                       61720          ['Transition1[0][0]']
#
#  Transition2 (TransitionBlock)               (None, None, None, 30)                       1830           ['DenseBlock2[0][0]']
#
#  DenseBlock3 (DenseBlock)                    (None, None, None, 90)                       138180         ['Transition2[0][0]']
#
#  Transition3 (TransitionBlock)               (None, None, None, 45)                       4095           ['DenseBlock3[0][0]']
#
#  DenseBlock4 (DenseBlock)                    (None, None, None, 125)                      246660         ['Transition3[0][0]']
#
#  Transition4 (TransitionBlock)               (None, None, None, 62)                       7812           ['DenseBlock4[0][0]']
#
#  DenseBlock5 (DenseBlock)                    (None, None, None, 162)                      387148         ['Transition4[0][0]']
#
#  Transition5 (TransitionBlock)               (None, None, None, 81)                       13203          ['DenseBlock5[0][0]']
#
#  DenseBlock6 (DenseBlock)                    (None, None, None, 201)                      560124         ['Transition5[0][0]']
#
#  Transition6 (TransitionBlock)               (None, None, None, 100)                      20200          ['DenseBlock6[0][0]']
#
#  conv2d_160 (Conv2D)                         (None, None, None, 120)                      108120         ['Transition6[0][0]']
#
#  spatial_dropout2d_51 (SpatialDropout2D)     (None, None, None, 120)                      0              ['conv2d_160[0][0]']
#
#  concatenate_27 (Concatenate)                (None, None, None, 140)                      0              ['conv2d_129[0][0]',
#                                                                                                           'spatial_dropout2d_51[0][0]']
#
#  TransitionBackboneLast (TransitionBlock)    (None, None, None, 120)                      16920          ['concatenate_27[0][0]']
#
#  SubpixelConvolution (SubpixelConvolutionBl  (None, None, None, 120)                      518880         ['TransitionBackboneLast[0][0]']
#  ock)
#
#  TransitionLast (TransitionBlock)            (None, None, None, 20)                       2420           ['SubpixelConvolution[0][0]']
#
#  conv_block_6 (ConvBlock)                    (None, None, None, 20)                       7585           ['TransitionLast[0][0]']
#
#  conv_block_7 (ConvBlock)                    (None, None, None, 1)                        197            ['conv_block_6[0][0]']
#
# ======================================================================================================================================================
# Total params: 2112794 (8.06 MB)
# Trainable params: 2108834 (8.04 MB)
# Non-trainable params: 3960 (15.47 KB)
# ______________________________________________________________________________________________________________________________________________________
# Epoch 1/50
# 72/72 [==============================] - 7s 23ms/step - loss: 1.0412 - val_loss: 0.7008
# Epoch 2/50
# 72/72 [==============================] - 1s 16ms/step - loss: 0.9396 - val_loss: 0.6905
# Epoch 3/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.9082 - val_loss: 0.7374
# Epoch 4/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8935 - val_loss: 0.7276
# Epoch 5/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8854 - val_loss: 0.7151
# Epoch 6/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8762 - val_loss: 0.6802
# Epoch 7/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8712 - val_loss: 0.6880
# Epoch 8/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8627 - val_loss: 0.6640
# Epoch 9/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8597 - val_loss: 1.0692
# Epoch 10/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8546 - val_loss: 0.7781
# Epoch 11/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8510 - val_loss: 0.6746
# Epoch 12/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8484 - val_loss: 0.6637
# Epoch 13/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8446 - val_loss: 0.6664
# Epoch 14/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8389 - val_loss: 0.6339
# Epoch 15/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8385 - val_loss: 1.0894
# Epoch 16/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8341 - val_loss: 1.2454
# Epoch 17/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8316 - val_loss: 2.1357
# Epoch 18/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8240 - val_loss: 1.9795
# Epoch 19/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8213 - val_loss: 0.8931
# Epoch 20/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8206 - val_loss: 0.8389
# Epoch 21/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8178 - val_loss: 1.2300
# Epoch 22/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8179 - val_loss: 0.8160
# Epoch 23/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8158 - val_loss: 1.1305
# Epoch 24/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8155 - val_loss: 0.6839
# Epoch 25/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8149 - val_loss: 0.9194
# Epoch 26/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8139 - val_loss: 0.8944
# Epoch 27/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8133 - val_loss: 1.1936
# Epoch 28/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8126 - val_loss: 0.7408
# Epoch 29/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8134 - val_loss: 0.7689
# Epoch 30/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8125 - val_loss: 0.9057
# Epoch 31/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8111 - val_loss: 0.7709
# Epoch 32/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8120 - val_loss: 0.7088
# Epoch 33/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8102 - val_loss: 0.8707
# Epoch 34/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8108 - val_loss: 0.8652
# Epoch 35/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8108 - val_loss: 0.7795
# Epoch 36/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8108 - val_loss: 0.6957
# Epoch 37/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8100 - val_loss: 0.8028
# Epoch 38/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8093 - val_loss: 0.8748
# Epoch 39/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8096 - val_loss: 0.7509
# Epoch 40/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8092 - val_loss: 0.9260
# Epoch 41/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8092 - val_loss: 0.6643
# Epoch 42/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8097 - val_loss: 0.8076
# Epoch 43/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8092 - val_loss: 0.7945
# Epoch 44/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8095 - val_loss: 0.9327
# Epoch 45/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8095 - val_loss: 0.9417
# Epoch 46/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8091 - val_loss: 1.3144
# Epoch 47/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8093 - val_loss: 0.7622
# Epoch 48/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8091 - val_loss: 0.8132
# Epoch 49/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8086 - val_loss: 0.5671
# Epoch 50/50
# 72/72 [==============================] - 1s 15ms/step - loss: 0.8085 - val_loss: 0.6908
# 8/8 [==============================] - 0s 4ms/step - loss: 1.8363
#
# Score on the test set: 1.8362507820129395
# --------------------------------------------------------------------------------
# Final running time: 0:01:02.094505
# --------------------------------------------------------------------------------

# %%
pred = dds.Predictor(
    trainer, 
    y_test, 
    scale=4, 
    array_in_hr=True,
    static_vars=None, 
    predictors=[y_z_test], 
    time_window=None,
    interpolation='inter_area', 
    batch_size=60,
    scaler=T2_scaler_train,
    save_path=None,
    save_fname=None,
    return_lr=True,
    device='CPU')

unscaled_y_pred, coarsened_array = pred.run()
# Out:
# --------------------------------------------------------------------------------
# Starting time: 2025-01-14 13:19:49
# --------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 391ms/step
# --------------------------------------------------------------------------------
# Final running time: 0:00:00.445396
# --------------------------------------------------------------------------------

# %%
pred1 = dds.Predictor(
    trainer, 
    x_test, 
    scale=4, 
    array_in_hr=False,
    static_vars=None, 
    predictors=[x_z_test], 
    time_window=None,
    interpolation='inter_area', 
    batch_size=60,
    scaler=T2_scaler_train,
    save_path=None,
    save_fname=None,
    return_lr=True,
    device='CPU')

unscaled_x_pred, coarsened_array1 = pred1.run()
# Out:
# --------------------------------------------------------------------------------
# Starting time: 2025-01-14 13:20:29
# --------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 49ms/step
# --------------------------------------------------------------------------------
# Final running time: 0:00:00.116334
# --------------------------------------------------------------------------------

# %%
unscaled_y_test = T2_scaler_train.inverse_transform(y_test)
ecv.plot((unscaled_y_test[0].values, unscaled_y_pred[0]), subplot_titles=('groundtruth t2m', 'downscaled t2m'))

# %%
unscaled_x_test = T2_scaler_train.inverse_transform(x_test)
unscaled_x_train = T2_scaler_train.inverse_transform(x_train)
ecv.plot((unscaled_x_test[0].values, unscaled_x_pred[0]), subplot_titles=('original t2m (NAM)', 'downscaled t2m'))

# %%
ecv.plot(unscaled_x_train.values)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :DynamicMap   [time]
#    :Image   [x,y]   (values)
